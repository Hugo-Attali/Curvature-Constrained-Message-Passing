# %% [markdown]
# \# **Notebook for reproducing CCAM results**

# %%
# Install required packages.
import os
import torch
os.environ['TORCH'] = torch.__version__
print(torch.__version__)

#!pip install -q torch-scatter -f https://data.pyg.org/whl/torch-${TORCH}.html
#!pip install -q torch-sparse -f https://data.pyg.org/whl/torch-${TORCH}.html
# !pip install -q git+https://github.com/pyg-team/pytorch_geometric.git

# Helper function for visualization.
# %matplotlib inline
import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

def visualize(h, color):
    z = TSNE(n_components=2).fit_transform(h.detach().cpu().numpy())

    plt.figure(figsize=(10,10))
    plt.xticks([])
    plt.yticks([])

    plt.scatter(z[:, 0], z[:, 1], s=70, c=color, cmap="Set2")
    plt.show()
# Out:
# 2.2.1+cu121
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
#   Building wheel for torch_geometric (pyproject.toml) ... done

# %%
# !pip install scipy==1.8.1
# Out:
# Collecting scipy==1.8.1
#   Downloading scipy-1.8.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (42.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 42.2/42.2 MB 9.7 MB/s eta 0:00:00
# Collecting numpy<1.25.0,>=1.17.3 (from scipy==1.8.1)
#   Downloading numpy-1.24.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 17.3/17.3 MB 14.3 MB/s eta 0:00:00
# Installing collected packages: numpy, scipy
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.25.2
#     Uninstalling numpy-1.25.2:
#       Successfully uninstalled numpy-1.25.2
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.4
#     Uninstalling scipy-1.11.4:
#       Successfully uninstalled scipy-1.11.4
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# jax 0.4.23 requires scipy>=1.9, but you have scipy 1.8.1 which is incompatible.
# jaxlib 0.4.23+cuda12.cudnn89 requires scipy>=1.9, but you have scipy 1.8.1 which is incompatible.
# pandas-stubs 2.0.3.230814 requires numpy>=1.25.0; python_version >= "3.9", but you have numpy 1.24.4 which is incompatible.
# Successfully installed numpy-1.24.4 scipy-1.8.1

# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
from torch_geometric.datasets import Planetoid, Amazon,WebKB,FB15k_237,HeterophilousGraphDataset,WikipediaNetwork,CitationFull,Actor
from torch_geometric.transforms import NormalizeFeatures
from torch_geometric.utils import homophily,add_self_loops, is_undirected,to_networkx,from_networkx,to_undirected, to_dense_adj, dense_to_sparse
import time

# %% [markdown]
# An example with the Texas dataset

# %%
#dataset = Planetoid(root='data/Planetoid', name='cora', transform=NormalizeFeatures())
#dataset = Amazon(root='data/amazon', name='Computers', transform=NormalizeFeatures())
#dataset = WebKB(root='data/WebKB', name='texas',transform = NormalizeFeatures())
#dataset = CitationFull(root='data/Citeseer', name='Citeseer', to_undirected = False)#
dataset = WikipediaNetwork(root='data/WikipediaNetwork', name='squirrel')
#dataset = HeterophilousGraphDataset(root='data/Roman-empire', name='Roman-empire')
#dataset = Actor(root='data/Actor')

print()
print(f'Dataset: {dataset}:')
print('======================')
print(f'Number of graphs: {len(dataset)}')
print(f'Number of features: {dataset.num_features}')
print(f'Number of classes: {dataset.num_classes}')

data = dataset[0]  # Get the first graph object.
data.y
print()
print(data)
print('===========================================================================================================')

# Gather some statistics about the graph.
print(f'Number of nodes: {data.num_nodes}')
print(f'Number of edges: {data.num_edges}')
print(f'Average node degree: {data.num_edges / data.num_nodes:.2f}')


print(f'Number of training nodes: {data.train_mask.sum()}')
print(f'Training node label rate: {int(data.train_mask.sum()) / data.num_nodes:.2f}')
print(f'Has isolated nodes: {data.has_isolated_nodes()}')
print(f'Has self-loops: {data.has_self_loops()}')
print(f'Is undirected: {data.is_undirected()}')

data_und = to_undirected(data.edge_index)
data_und,_= add_self_loops(data_und, num_nodes=data.num_nodes)
# Out:
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/new_data/squirrel/out1_node_feature_label.txt
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/new_data/squirrel/out1_graph_edges.txt
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_0.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_1.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_2.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_3.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_4.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_5.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_6.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_7.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_8.npz
# Downloading https://raw.githubusercontent.com/graphdml-uiuc-jlu/geom-gcn/f1fc0d14b3b019c562737240d06ec83b07d16a8f/splits/squirrel_split_0.6_0.2_9.npz
# Processing...
# Dataset: WikipediaNetwork():
# ======================
# Number of graphs: 1
# Number of features: 2089
# Number of classes: 5
#
# Data(x=[5201, 2089], edge_index=[2, 217073], y=[5201], train_mask=[5201, 10], val_mask=[5201, 10], test_mask=[5201, 10])
# ===========================================================================================================
# Number of nodes: 5201
# Number of edges: 217073
# Average node degree: 41.74
# Number of training nodes: 24960
# Training node label rate: 4.80
# Has isolated nodes: False
# Has self-loops: True
# Is undirected: False
# Done!

# %%
#rom bf_curvature import *
'''
# !cp /content/drive/MyDrive/curvaadj/FAUX_bf_curvature.py bf_curvature.py
import bf_curvature

import numpy as np
start_time = time.time()
C = bf_curvature.balanced_forman_curvature(data_und,data.num_nodes,False)
C.shape
C.max()
print(time.time() - start_time)
mat_ricci=np.zeros((data.num_nodes,data.num_nodes))
mat_riccim=np.zeros((data.num_nodes,data.num_nodes))

C.max()

torch.where(adj[1] > 0)[0]
np.sum(mat_riccim)
#mat_ricci = np.where(C >= mean_C, C, 0)
#mat_riccim = np.where(C <= mean_C, C, 0)

# %% [markdown]
# Utilisation de la courbure de Forman Balanced (TOPPING ICLR 2022) (Besoin de telecharger les matrices de courbure pré-calculer )
#
#
# ---
#
#
#
# ---

# %%
import pickle
C = open('/content/drive/MyDrive/curvaadj/courbure-bfc-cora.pk','rb') #Récuperation de la matrice de courbure pré calculer en amont
C =pickle.load(C)

# %%
values = C[data.edge_index[0], data.edge_index[1]]
values.shape
moyenne_arretes = torch.mean(values)
torch.nanmean(values)
print(moyenne_arretes)
mat_ricci = np.where(C.cpu() >= moyenne_arretes.cpu(), C.cpu(), 0)
mat_riccim = np.where(C.cpu() <= moyenne_arretes.cpu(), C.cpu(), 0)
# Out:
# tensor(-0.3010, device='cuda:0')

# %%
new_adj,_ = dense_to_sparse(new_adj)
new_adj,_= add_self_loops(new_adj, num_nodes=data.num_nodes)

# %% [markdown]
# ---

# %% [markdown]
# Utilisation de la courbure de Augmented Forman et Olliver

# %%
# !pip install GraphRicciCurvature
from GraphRicciCurvature.OllivierRicci import OllivierRicci
import networkx as nx
# load GraphRicciCuravture package
from GraphRicciCurvature.OllivierRicci import OllivierRicci
from GraphRicciCurvature.FormanRicci import FormanRicci


import networkx as nx
import numpy as np
import math
# %matplotlib inline
import matplotlib.pyplot as plt

# to print logs in jupyter notebook
import logging
logging.basicConfig(format='%(levelname)s:%(message)s', level=logging.ERROR)

# load GraphRicciCuravture package
from GraphRicciCurvature.OllivierRicci import OllivierRicci
from GraphRicciCurvature.FormanRicci import FormanRicci
# Out:
# Collecting GraphRicciCurvature
#   Downloading GraphRicciCurvature-0.5.3.1-py3-none-any.whl (23 kB)
# Requirement already satisfied: cython in /usr/local/lib/python3.10/dist-packages (from GraphRicciCurvature) (3.0.10)
# Requirement already satisfied: numpy in /usr/local/lib/python3.10/dist-packages (from GraphRicciCurvature) (1.25.2)
# Requirement already satisfied: scipy>=1.0 in /usr/local/lib/python3.10/dist-packages (from GraphRicciCurvature) (1.11.4)
# Requirement already satisfied: networkx>=2.0 in /usr/local/lib/python3.10/dist-packages (from GraphRicciCurvature) (3.2.1)
# Collecting pot>=0.8.0 (from GraphRicciCurvature)
#   Downloading POT-0.9.3-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (823 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 823.0/823.0 kB 7.2 MB/s eta 0:00:00
# Requirement already satisfied: packaging in /usr/local/lib/python3.10/dist-packages (from GraphRicciCurvature) (24.0)
# Collecting networkit>=6.1 (from GraphRicciCurvature)
#   Downloading networkit-11.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (13.7 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.7/13.7 MB 31.1 MB/s eta 0:00:00
# Requirement already satisfied: python-louvain in /usr/local/lib/python3.10/dist-packages (from GraphRicciCurvature) (0.16)
# Installing collected packages: pot, networkit, GraphRicciCurvature
# Successfully installed GraphRicciCurvature-0.5.3.1 networkit-11.0 pot-0.9.3
# 			<script type="text/javascript">
# 			<!--
#
# 			{
# 				var element = document.getElementById('NetworKit_script');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('script');
# 				element.type = 'text/javascript';
# 				element.innerHTML = 'function NetworKit_pageEmbed(id) { var i, j; var elements; elements = document.getElementById(id).getElementsByClassName("Plot"); for (i=0; i<elements.length; i++) { elements[i].id = id + "_Plot_" + i; var data = elements[i].getAttribute("data-image").split("|"); elements[i].removeAttribute("data-image"); var content = "<div class=\\"Image\\" id=\\"" + elements[i].id + "_Image\\" />"; elements[i].innerHTML = content; elements[i].setAttribute("data-image-index", 0); elements[i].setAttribute("data-image-length", data.length); for (j=0; j<data.length; j++) { elements[i].setAttribute("data-image-" + j, data[j]); } NetworKit_plotUpdate(elements[i]); elements[i].onclick = function (e) { NetworKit_overlayShow((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("HeatCell"); for (i=0; i<elements.length; i++) { var data = parseFloat(elements[i].getAttribute("data-heat")); var color = "#00FF00"; if (data <= 1 && data > 0) { color = "hsla(0, 100%, 75%, " + (data) + ")"; } else if (data <= 0 && data >= -1) { color = "hsla(240, 100%, 75%, " + (-data) + ")"; } elements[i].style.backgroundColor = color; } elements = document.getElementById(id).getElementsByClassName("Details"); for (i=0; i<elements.length; i++) { elements[i].setAttribute("data-title", "-"); NetworKit_toggleDetails(elements[i]); elements[i].onclick = function (e) { NetworKit_toggleDetails((e.target) ? e.target : e.srcElement); } } elements = document.getElementById(id).getElementsByClassName("MathValue"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "nan") { elements[i].parentNode.innerHTML = "" } } elements = document.getElementById(id).getElementsByClassName("SubCategory"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } elements = document.getElementById(id).getElementsByClassName("Category"); for (i=elements.length-1; i>=0; i--) { value = elements[i].innerHTML.trim(); if (value === "") { elements[i].parentNode.removeChild(elements[i]) } } var isFirefox = false; try { isFirefox = typeof InstallTrigger !== "undefined"; } catch (e) {} if (!isFirefox) { alert("Currently the function\'s output is only fully supported by Firefox."); } } function NetworKit_plotUpdate(source) { var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById(source.id + "_Image"); image.style.backgroundImage = "url(" + data + ")"; } function NetworKit_showElement(id, show) { var element = document.getElementById(id); element.style.display = (show) ? "block" : "none"; } function NetworKit_overlayShow(source) { NetworKit_overlayUpdate(source); NetworKit_showElement("NetworKit_Overlay", true); } function NetworKit_overlayUpdate(source) { document.getElementById("NetworKit_Overlay_Title").innerHTML = source.title; var index = source.getAttribute("data-image-index"); var data = source.getAttribute("data-image-" + index); var image = document.getElementById("NetworKit_Overlay_Image"); image.setAttribute("data-id", source.id); image.style.backgroundImage = "url(" + data + ")"; var link = document.getElementById("NetworKit_Overlay_Toolbar_Bottom_Save"); link.href = data; link.download = source.title + ".svg"; } function NetworKit_overlayImageShift(delta) { var image = document.getElementById("NetworKit_Overlay_Image"); var source = document.getElementById(image.getAttribute("data-id")); var index = parseInt(source.getAttribute("data-image-index")); var length = parseInt(source.getAttribute("data-image-length")); var index = (index+delta) % length; if (index < 0) { index = length + index; } source.setAttribute("data-image-index", index); NetworKit_overlayUpdate(source); } function NetworKit_toggleDetails(source) { var childs = source.children; var show = false; if (source.getAttribute("data-title") == "-") { ...
# 				element.setAttribute('id', 'NetworKit_script');
# 				document.head.appendChild(element);
# 			}
#
#
# 			{
# 				var element = document.getElementById('NetworKit_style');
# 				if (element) {
# 					element.parentNode.removeChild(element);
# 				}
# 				element = document.createElement('style');
# 				element.type = 'text/css';
# 				element.innerHTML = '.NetworKit_Page { font-family: Arial, Helvetica, sans-serif; font-size: 14px; } .NetworKit_Page .Value:before { font-family: Arial, Helvetica, sans-serif; font-size: 1.05em; content: attr(data-title) ":"; margin-left: -2.5em; padding-right: 0.5em; } .NetworKit_Page .Details .Value:before { display: block; } .NetworKit_Page .Value { font-family: monospace; white-space: pre; padding-left: 2.5em; white-space: -moz-pre-wrap !important; white-space: -pre-wrap; white-space: -o-pre-wrap; white-space: pre-wrap; word-wrap: break-word; tab-size: 4; -moz-tab-size: 4; } .NetworKit_Page .Category { clear: both; padding-left: 1em; margin-bottom: 1.5em; } .NetworKit_Page .Category:before { content: attr(data-title); font-size: 1.75em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory { margin-bottom: 1.5em; padding-left: 1em; } .NetworKit_Page .SubCategory:before { font-size: 1.6em; display: block; margin-left: -0.8em; margin-bottom: 0.5em; } .NetworKit_Page .SubCategory[data-title]:before { content: attr(data-title); } .NetworKit_Page .Block { display: block; } .NetworKit_Page .Block:after { content: "."; visibility: hidden; display: block; height: 0; clear: both; } .NetworKit_Page .Block .Thumbnail_Overview, .NetworKit_Page .Block .Thumbnail_ScatterPlot { width: 260px; float: left; } .NetworKit_Page .Block .Thumbnail_Overview img, .NetworKit_Page .Block .Thumbnail_ScatterPlot img { width: 260px; } .NetworKit_Page .Block .Thumbnail_Overview:before, .NetworKit_Page .Block .Thumbnail_ScatterPlot:before { display: block; text-align: center; font-weight: bold; } .NetworKit_Page .Block .Thumbnail_Overview:before { content: attr(data-title); } .NetworKit_Page .HeatCell { font-family: "Courier New", Courier, monospace; cursor: pointer; } .NetworKit_Page .HeatCell, .NetworKit_Page .HeatCellName { display: inline; padding: 0.1em; margin-right: 2px; background-color: #FFFFFF } .NetworKit_Page .HeatCellName { margin-left: 0.25em; } .NetworKit_Page .HeatCell:before { content: attr(data-heat); display: inline-block; color: #000000; width: 4em; text-align: center; } .NetworKit_Page .Measure { clear: both; } .NetworKit_Page .Measure .Details { cursor: pointer; } .NetworKit_Page .Measure .Details:before { content: "[" attr(data-title) "]"; display: block; } .NetworKit_Page .Measure .Details .Value { border-left: 1px dotted black; margin-left: 0.4em; padding-left: 3.5em; pointer-events: none; } .NetworKit_Page .Measure .Details .Spacer:before { content: "."; opacity: 0.0; pointer-events: none; } .NetworKit_Page .Measure .Plot { width: 440px; height: 440px; cursor: pointer; float: left; margin-left: -0.9em; margin-right: 20px; } .NetworKit_Page .Measure .Plot .Image { background-repeat: no-repeat; background-position: center center; background-size: contain; height: 100%; pointer-events: none; } .NetworKit_Page .Measure .Stat { width: 500px; float: left; } .NetworKit_Page .Measure .Stat .Group { padding-left: 1.25em; margin-bottom: 0.75em; } .NetworKit_Page .Measure .Stat .Group .Title { font-size: 1.1em; display: block; margin-bottom: 0.3em; margin-left: -0.75em;

# %% [markdown]
# Calculate curvature according to Ollivier

# %%
def mean_courbure(G,curvature="formanCurvature") : #formanCurvature/ricciCurvature
    total_forman_curvature = 0
    nombre_d_elements = 0
    for sommet, voisins in G_curv.adj.items():
        for voisin, attributs in voisins.items():
            forman_curvature = attributs.get(curvature, None)
            if forman_curvature is not None:
                total_forman_curvature += forman_curvature
                nombre_d_elements += 1
    if nombre_d_elements > 0:
        moyenne_forman_curvature = total_forman_curvature / nombre_d_elements
        print("Moyenne des valeurs de formanCurvature :", moyenne_forman_curvature)
    else:
        print("Aucune valeur de formanCurvature trouvée.")
    return moyenne_forman_curvature

# %%
#curvature = "ricciCurvature"/formanCurvature

def show_results(G):
    # Print the first five results
    print("Karate Club Graph, first 5 edges: ")
    for n1,n2 in list(G.edges())[:5]:
        print("Ollivier-Ricci curvature of edge (%s,%s) is %f" % (n1 ,n2, G[n1][n2]["formanCurvature"]))

    # Plot the histogram of Ricci curvatures
    plt.subplot(2, 1, 1)
    ricci_curvtures = nx.get_edge_attributes(G, "formanCurvature").values()

    values = list(ricci_curvtures)
    values.sort()
    print(values)

    # Calcul du premier quartile (Q1)
    n = len(values)

    squash_index = int(n * 0.1)
    print(squash_index)  # Index correspondant au premier deciles
    q1 = values[squash_index]


    n = len(values)

    smooth_index = int(n * 0.9)
    print(smooth_index)  # Index correspondant au premier deciles

     # Index correspondant au derniere deciles
    q10 = values[smooth_index]


    return q1,q10


Q1,Q10 = show_results(G_curv)
# Out:
# 12.0

# %%
A = torch.squeeze(to_dense_adj(data_und)).numpy()
G=nx.Graph(A)
start_time = time.time()
#curvature = "ricciCurvature" #Coubure d'ollivier
#orc = OllivierRicci(G, alpha=0.5, verbose="TRACE")#Coubure d'ollivier
curvature = "formanCurvature" #Coubure de forman
orc = FormanRicci(G)
start_time = time.time()
orc.compute_ricci_curvature()
G_curv = orc.G.copy()
print(time.time() - start_time)


mat_ricci=np.zeros((data.num_nodes,data.num_nodes))
mat_riccim=np.zeros((data.num_nodes,data.num_nodes))
mat_ricci_ent=np.zeros((data.num_nodes,data.num_nodes))

mean_mr = mean_courbure(G)


for a,i in enumerate(np.unique(G_curv)):
    for j in list(G_curv.neighbors(a)):
        if G_curv[i][j][curvature]>=Q1 :
            mat_ricci[a][j]=G_curv[i][j][curvature]
        if G_curv[i][j][curvature]<=Q1 :
            mat_riccim[a][j]=G_curv[i][j][curvature]
# Out:
# 209.5550479888916
# Moyenne des valeurs de formanCurvature : -392.22435303795675

# %% [markdown]
# Filtrer la matrice d'adjancence selon la courbure

# %%
curvp = torch.Tensor(mat_ricci)
curvm = torch.Tensor(mat_riccim)
curvp = curvp.nonzero().t().contiguous()
curvm = curvm.nonzero().t().contiguous()

edge_index_curvp,_ = add_self_loops(curvp, num_nodes=data.num_nodes)
edge_index_curvm,_ = add_self_loops(curvm, num_nodes=data.num_nodes)

edge_index_curvp = to_undirected(edge_index_curvp)
edge_index_curvm = to_undirected(edge_index_curvm)
is_undirected(edge_index_curvm)
# Out:
# True

# %% [markdown]
# Measurement of homophily on edges presented by Zhu et al. and the measurement Curvature-Constrained homophily

# %%
print(homophily(data_und, data.y))
print(homophily(edge_index_curvp, data.y))
print(homophily(edge_index_curvm, data.y))
# Out:
# 0.23246784508228302
# 0.2294272780418396
# 0.34220656752586365

# %% [markdown]
# Possibly building a two-hop based on curvature.

# %%
from torch_geometric.utils import add_self_loops
num_nodes = data.num_nodes
new_edge_index = []

def build_two_hop(mat_adj):

    for node in range(num_nodes):
        neighbors = mat_adj[1][mat_adj[0] == node]

        for neighbor in neighbors:
            neighbors_of_neighbor = mat_adj[1][mat_adj[0] == neighbor]

            neighbors_of_neighbor = neighbors_of_neighbor[neighbors_of_neighbor != node]

            for neighbor_of_neighbor in neighbors_of_neighbor:
                new_edge_index.append([node, neighbor_of_neighbor.item()])

    two_hop_tensor = torch.tensor(new_edge_index, dtype=torch.long).t()
    two_hop_tensor,_ = add_self_loops(two_hop_tensor, num_nodes=data.num_nodes)
    return two_hop_tensor

two_hop_tensor = build_two_hop(edge_index_curvm)#edge_index_curvm/curvp => matrice d'adjance négative/positive
print(homophily(two_hop_tensor, data.y))
is_undirected(two_hop_tensor)
two_hop_tensor.shape
# Out:
# 0.5602510571479797
# torch.Size([2, 11311])

# %% [markdown]
# GCN

# %%
from torch_geometric.nn import GCNConv
import torch.nn.functional as F
class GCN(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.conv1 = GCNConv(dataset.num_features, hidden_channels)
        self.conv2 = GCNConv(hidden_channels, dataset.num_classes)

    def forward(self, x, edge_index):
        x = self.conv1(x.to(device), edge_index_curvp.to(device))
        x = x.relu()
        x = F.dropout(x.to(device), p=0.5, training=self.training)
        x = self.conv2(x.to(device), edge_index_curvp.to(device))
        return x.to(device)

# %% [markdown]
# GAT

# %%
from torch_geometric.nn import GATConv
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

class GAT(torch.nn.Module):
    def __init__(self, hidden_channels):
        super().__init__()
        self.conv1 = GATConv(dataset.num_features, hidden_channels,heads=8,dropout= 0.5)
        self.conv2 = GATConv(hidden_channels*8, dataset.num_classes,heads=1,dropout= 0.5)

    def forward(self, x, edge_index):
        x = F.elu(self.conv1(x.to(device), two_hop_tensor.to(device)))
        x = F.dropout(x.to(device), p=0.5, training=self.training)
        x = self.conv2(x.to(device), two_hop_tensor.to(device))
        return x.to(device)

# %%
criterion = torch.nn.CrossEntropyLoss()

def train(t,v):
      model.train()
      optimizer.zero_grad()  # Clear gradients.
      out = model(data.x.to(device), data.edge_index.to(device))  # Perform a single forward pass.
      loss = criterion(out[data_train_mask], data.y.to(device)[data_train_mask])  # Compute the loss solely based on the training nodes.
      val_loss = criterion(out[v].to(device), data.y.to(device)[v])  # Compute the loss solely based on the val nodes.
      loss.backward() # Derive gradients.
      #val_loss.backward()  # Derive gradients.
      optimizer.step()  # Update parameters based on gradients.
      return loss,val_loss
def test(mask):
      model.eval()
      out = model(data.x.to(device), data.edge_index.to(device))
      pred = out.argmax(dim=1)  # Use the class with highest probability.
      correct = pred[mask] == data.y.to(device)[mask]  # Check against ground-truth labels.
      acc = int(correct.sum()) / int(mask.sum())  # Derive ratio of correct predictions.
      return acc

# %%
import time
import numpy as np
ramdom = True
moy = []
ep = []
T = []
p_m =[]
nb_runs = 10
hidden_channels = 48
lr = 0.005
weight_decay = 5e-5
moy = []
ep = []
for runs in range(nb_runs):
    model = GCN(hidden_channels=hidden_channels).to(device)
    #model = GAT(hidden_channels=hidden_channels).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    criterion = torch.nn.CrossEntropyLoss()
    print("runs", runs)
    start_time = time.time()
    shuffled_indices = torch.randperm(len(data.y))
    if ramdom == True :


        indices = [False for i in range(len(data.y))]
        mask_train = [True if i in shuffled_indices[:20*(torch.max(data.y)+1)] else False for i in range(len(indices))]
        mask_val = [True if i in shuffled_indices[20*(torch.max(data.y)+1):20*(torch.max(data.y)+1)+500] else False for i in range(len(indices))]
        mask_test = [True if i in shuffled_indices[20*(torch.max(data.y)+1)+500:20*(torch.max(data.y)+1)+1500] else False for i in range(len(indices))]

        data_train_mask = torch.tensor(mask_train)
        data_val_mask = torch.tensor(mask_val)
        data_test_mask = torch.tensor(mask_test)


    indices = [False for i in range(len(data.y))]
    mask_train = [True if i in shuffled_indices[:int(0.6*len(data.y))] else False for i in range(len(indices))]
    mask_val = [True if i in shuffled_indices[int(0.6*len(data.y)):int(0.8*len(data.y))] else False for i in range(len(indices))]
    mask_test = [True if i in shuffled_indices[int(0.8*len(data.y)):len(data.y)] else False for i in range(len(indices))]


    data_train_mask = torch.tensor(mask_train)
    data_val_mask = torch.tensor(mask_val)
    data_test_mask = torch.tensor(mask_test)

    best_val_acc = 0
    i=0
    for epoch in range(1, 2001):
        loss,val_loss = train(data_train_mask,data_val_mask)
        val_acc = test(data_val_mask)
        train_acc = test(data_train_mask)
        test_acc = test(data_test_mask)
        if val_acc > best_val_acc :
          best_val_acc = val_acc
          Test_acc = test_acc
          i=0
        i=i+1
        print(f'Epoch: {epoch:03d}, Loss: {loss:.4f},Train_acc: {train_acc:.4f}, val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f},test_acc: {test_acc:.4f}')
        #print(i)
        if i == 100 :
          break

    T.append(time.time() - start_time)
    print(f'Test Accuracy: {Test_acc:.4f}')
    moy.append(Test_acc)
    ep.append(epoch)
print("-------------------------" )
print("mod" , model)
print("hidden_channels" , hidden_channels)
print("weight_decay" , weight_decay)
print("lr" , lr)
print("moyenne" , np.mean(moy))
print("std" , np.std(moy))
print("temps" , np.mean(T))
print((2*(np.std(moy))/(10))*100)


print("-------------------------" )
# Out:
# runs 0
# Epoch: 001, Loss: 1.6108,Train_acc: 0.2071, val_loss: 1.6108, val_acc: 0.1865,test_acc: 0.1921
# Epoch: 002, Loss: 1.5860,Train_acc: 0.2074, val_loss: 1.5872, val_acc: 0.1865,test_acc: 0.1921
# Epoch: 003, Loss: 1.5791,Train_acc: 0.2074, val_loss: 1.5850, val_acc: 0.1865,test_acc: 0.1921
# Epoch: 004, Loss: 1.5703,Train_acc: 0.2170, val_loss: 1.5797, val_acc: 0.1942,test_acc: 0.1950
# Epoch: 005, Loss: 1.5610,Train_acc: 0.2571, val_loss: 1.5721, val_acc: 0.2231,test_acc: 0.2219
# Epoch: 006, Loss: 1.5490,Train_acc: 0.2955, val_loss: 1.5579, val_acc: 0.2510,test_acc: 0.2440
# Epoch: 007, Loss: 1.5393,Train_acc: 0.3356, val_loss: 1.5522, val_acc: 0.2817,test_acc: 0.2824
# Epoch: 008, Loss: 1.5300,Train_acc: 0.3554, val_loss: 1.5465, val_acc: 0.3067,test_acc: 0.3141
# Epoch: 009, Loss: 1.5217,Train_acc: 0.3631, val_loss: 1.5382, val_acc: 0.3106,test_acc: 0.3170
# Epoch: 010, Loss: 1.5092,Train_acc: 0.3769, val_loss: 1.5321, val_acc: 0.3183,test_acc: 0.3266
# Epoch: 011, Loss: 1.4985,Train_acc: 0.3891, val_loss: 1.5254, val_acc: 0.3183,test_acc: 0.3305
# Epoch: 012, Loss: 1.4887,Train_acc: 0.3949, val_loss: 1.5252, val_acc: 0.3260,test_acc: 0.3391
# Epoch: 013, Loss: 1.4776,Train_acc: 0.4013, val_loss: 1.5163, val_acc: 0.3356,test_acc: 0.3372
# Epoch: 014, Loss: 1.4709,Train_acc: 0.4045, val_loss: 1.5122, val_acc: 0.3462,test_acc: 0.3449
# Epoch: 015, Loss: 1.4628,Train_acc: 0.4208, val_loss: 1.5063, val_acc: 0.3452,test_acc: 0.3564
# Epoch: 016, Loss: 1.4503,Train_acc: 0.4353, val_loss: 1.5000, val_acc: 0.3538,test_acc: 0.3727
# Epoch: 017, Loss: 1.4365,Train_acc: 0.4471, val_loss: 1.4938, val_acc: 0.3740,test_acc: 0.3862
# Epoch: 018, Loss: 1.4308,Train_acc: 0.4615, val_loss: 1.4861, val_acc: 0.3808,test_acc: 0.4025
# Epoch: 019, Loss: 1.4191,Train_acc: 0.4660, val_loss: 1.4800, val_acc: 0.3721,test_acc: 0.4035
# Epoch: 020, Loss: 1.4095,Train_acc: 0.4609, val_loss: 1.4829, val_acc: 0.3750,test_acc: 0.3900
# Epoch: 021, Loss: 1.4001,Train_acc: 0.4593, val_loss: 1.4719, val_acc: 0.3760,test_acc: 0.3842
# Epoch: 022, Loss: 1.3919,Train_acc: 0.4612, val_loss: 1.4808, val_acc: 0.3721,test_acc: 0.3842
# Epoch: 023, Loss: 1.3761,Train_acc: 0.4683, val_loss: 1.4657, val_acc: 0.3798,test_acc: 0.3958
# Epoch: 024, Loss: 1.3677,Train_acc: 0.4830, val_loss: 1.4620, val_acc: 0.3933,test_acc: 0.4169
# Epoch: 025, Loss: 1.3626,Train_acc: 0.4872, val_loss: 1.4665, val_acc: 0.3981,test_acc: 0.4217
# Epoch: 026, Loss: 1.3514,Train_acc: 0.4936, val_loss: 1.4605, val_acc: 0.3913,test_acc: 0.4179
# Epoch: 027, Loss: 1.3445,Train_acc: 0.4971, val_loss: 1.4512, val_acc: 0.3952,test_acc: 0.4207
# Epoch: 028, Loss: 1.3306,Train_acc: 0.4946, val_loss: 1.4561, val_acc: 0.3923,test_acc: 0.4236
# Epoch: 029, Loss: 1.3234,Train_acc: 0.5010, val_loss: 1.4482, val_acc: 0.3875,test_acc: 0.4284
# Epoch: 030, Loss: 1.3164,Train_acc: 0.5099, val_loss: 1.4456, val_acc: 0.3894,test_acc: 0.4246
# Epoch: 031, Loss: 1.3090,Train_acc: 0.5160, val_loss: 1.4459, val_acc: 0.3865,test_acc: 0.4265
# Epoch: 032, Loss: 1.2983,Train_acc: 0.5186, val_loss: 1.4563, val_acc: 0.3933,test_acc: 0.4217
# Epoch: 033, Loss: 1.2909,Train_acc: 0.5106, val_loss: 1.4400, val_acc: 0.3913,test_acc: 0.4313
# Epoch: 034, Loss: 1.2764,Train_acc: 0.5135, val_loss: 1.4363, val_acc: 0.3952,test_acc: 0.4323
# Epoch: 035, Loss: 1.2765,Train_acc: 0.5295, val_loss: 1.4335, val_acc: 0.3981,test_acc: 0.4313
# Epoch: 036, Loss: 1.2672,Train_acc: 0.5324, val_loss: 1.4267, val_acc: 0.4048,test_acc: 0.4361
# Epoch: 037, Loss: 1.2629,Train_acc: 0.5353, val_loss: 1.4362, val_acc: 0.4087,test_acc: 0.4342
# Epoch: 038, Loss: 1.2575,Train_acc: 0.5381, val_loss: 1.4256, val_acc: 0.4077,test_acc: 0.4361
# Epoch: 039, Loss: 1.2456,Train_acc: 0.5404, val_loss: 1.4413, val_acc: 0.4106,test_acc: 0.4294
# Epoch: 040, Loss: 1.2323,Train_acc: 0.5433, val_loss: 1.4212, val_acc: 0.4183,test_acc: 0.4380
# Epoch: 041, Loss: 1.2330,Train_acc: 0.5471, val_loss: 1.4331, val_acc: 0.4154,test_acc: 0.4380
# Epoch: 042, Loss: 1.2265,Train_acc: 0.5494, val_loss: 1.4429, val_acc: 0.4163,test_acc: 0.4352
# Epoch: 043, Loss: 1.2144,Train_acc: 0.5497, val_loss: 1.4268, val_acc: 0.4173,test_acc: 0.4380
# Epoch: 044, Loss: 1.2019,Train_acc: 0.5542, val_loss: 1.4104, val_acc: 0.4183,test_acc: 0.4428
# Epoch: 045, Loss: 1.2082,Train_acc: 0.5619, val_loss: 1.4278, val_acc: 0.4221,test_acc: 0.4390
# Epoch: 046, Loss: 1.2008,Train_acc: 0.5619, val_loss: 1.4256, val_acc: 0.4240,test_acc: 0.4400
# Epoch: 047, Loss: 1.1945,Train_acc: 0.5638, val_loss: 1.4293, val_acc: 0.4183,test_acc: 0.4390
# Epoch: 048, Loss: 1.1858,Train_acc: 0.5644, val_loss: 1.4180, val_acc: 0.4202,test_acc: 0.4380
# Epoch: 049, Loss: 1.1810,Train_acc: 0.5696, val_loss: 1.4129, val_acc: 0.4317,test_acc: 0.4448
# Epoch: 050, Loss: 1.1738,Train_acc: 0.5673, val_loss: 1.4238, val_acc: 0.4231,test_acc: 0.4476
# Epoch: 051, Loss: 1.1694,Train_acc: 0.5721, val_loss: 1.4251, val_acc: 0.4298,test_acc: 0.4515
# Epoch: 052, Loss: 1.1653,Train_acc: 0.5750, val_loss: 1.4178, val_acc: 0.4288,test_acc: 0.4486
# Epoch: 053, Loss: 1.1590,Train_acc: 0.5756, val_loss: 1.4205, val_acc: 0.4279,test_acc: 0.4428
# Epoch: 054, Loss: 1.1573,Train_acc: 0.5785, val_loss: 1.4231, val_acc: 0.4279,test_acc: 0.4457
# Epoch: 055, Loss: 1.1555,Train_acc: 0.5801, val_loss: 1.4183, val_acc: 0.4346,test_acc: 0.4467
# Epoch: 056, Loss: 1.1418,Train_acc: 0.5792, val_loss: 1.4247, val_acc: 0.4327,test_acc: 0.4544
# Epoch: 057, Loss: 1.1404,Train_acc: 0.5801, val_loss: 1.4224, val_acc: 0.4327,test_acc: 0.4544
# Epoch: 058, Loss: 1.1361,Train_acc: 0.5859, val_loss: 1.4209, val_acc: 0.4394,test_acc: 0.4448
# Epoch: 059, Loss: 1.1311,Train_acc: 0.5837, val_loss: 1.4307, val_acc: 0.4260,test_acc: 0.4428
# Epoch: 060, Loss: 1.1317,Train_acc: 0.5872, val_loss: 1.4277, val_acc: 0.4346,test_acc: 0.4457
# Epoch: 061, Loss: 1.1237,Train_acc: 0.5859, val_loss: 1.4312, val_acc: 0.4433,test_acc: 0.4553
# Epoch: 062, Loss: 1.1182,Train_acc: 0.5923, val_loss: 1.4385, val_acc: 0.4365,test_acc: 0.4524
# Epoch: 063, Loss: 1.1145,Train_acc: 0.5952, val_loss: 1.4165, val_acc: 0.4404,test_acc: 0.4476
# Epoch: 064, Loss: 1.1080,Train_acc: 0.5974, val_loss: 1.4338, val_acc: 0.4404,test_acc: 0.4476
# Epoch: 065, Loss: 1.1037,Train_acc: 0.5968, val_loss: 1.4391, val_acc: 0.4500,test_acc: 0.4496
# Epoch: 066, Loss: 1.1046,Train_acc: 0.6006, val_loss: 1.4221, val_acc: 0.4462,test_acc: 0.4524
# Epoch: 067, Loss: 1.1018,Train_acc: 0.6051, val_loss: 1.4262, val_acc: 0.4413,test_acc: 0.4563
# Epoch: 068, Loss: 1.1018,Train_acc: 0.6083, val_loss: 1.4331, val_acc: 0.4404,test_acc: 0.4563
# Epoch: 069, Loss: 1.0894,Train_acc: 0.6109, val_loss: 1.4096, val_acc: 0.4471,test_acc: 0.4534
# Epoch: 070, Loss: 1.0855,Train_acc: 0.6022, val_loss: 1.4265, val_acc: 0.4462,test_acc: 0.4524
# Epoch: 071, Loss: 1.0846,Train_acc: 0.6058, val_loss: 1.4382, val_acc: 0.4490,test_acc: 0.4534
# Epoch: 072, Loss: 1.0798,Train_acc: 0.6106, val_loss: 1.4497, val_acc: 0.4490,test_acc: 0.4544
# Epoch: 073, Loss: 1.0794,Train_acc: 0.6160, val_loss: 1.4459, val_acc: 0.4481,test_acc: 0.4601
# Epoch: 074, Loss: 1.0743,Train_acc: 0.6173, val_loss: 1.4243, val_acc: 0.4500,test_acc: 0.4630
# Epoch: 075, Loss: 1.0725,Train_acc: 0.6183, val_loss: 1.4451, val_acc: 0.4538,test_acc: 0.4621
# Epoch: 076, Loss: 1.0639,Train_acc: 0.6135, val_loss: 1.4389, val_acc: 0.4481,test_acc: 0.4582
# Epoch: 077, Loss: 1.0626,Train_acc: 0.6138, val_loss: 1.4339, val_acc: 0.4471,test_acc: 0.4621
# Epoch: 078, Loss: 1.0570,Train_acc: 0.6218, val_loss: 1.4350, val_acc: 0.4500,test_acc: 0.4621
# Epoch: 079, Loss: 1.0514,Train_acc: 0.6247, val_loss: 1.4370, val_acc: 0.4510,test_acc: 0.4640
# Epoch: 080, Loss: 1.0470,Train_acc: 0.6269, val_loss: 1.4400, val_acc: 0.4394,test_acc: 0.4582
# Epoch: 081, Loss: 1.0492,Train_acc: 0.6301, val_loss: 1.4478, val_acc: 0.4510,test_acc: 0.4601
# Epoch: 082, Loss: 1.0470,Train_acc: 0.6240, val_loss: 1.4366, val_acc: 0.4529,test_acc: 0.4601
# Epoch: 083, Loss: 1.0457,Train_acc: 0.6244, val_loss: 1.4157, val_acc: 0.4490,test_acc: 0.4630
# Epoch: 084, Loss: 1.0462,Train_acc: 0.6337, val_loss: 1.4398, val_acc: 0.4558,test_acc: 0.4630
# Epoch: 085, Loss: 1.0393,Train_acc: 0.6359, val_loss: 1.4294, val_acc: 0.4519,test_acc: 0.4678
# Epoch: 086, Loss: 1.0373,Train_acc: 0.6375, val_loss: 1.4419, val_acc: 0.4529,test_acc: 0.4553
# Epoch: 087, Loss: 1.0356,Train_acc: 0.6272, val_loss: 1.4383, val_acc: 0.4538,test_acc: 0.4630
# Epoch: 088, Loss: 1.0285,Train_acc: 0.6343, val_loss: 1.4510, val_acc: 0.4558,test_acc: 0.4621
# Epoch: 089, Loss: 1.0306,Train_acc: 0.6365, val_loss: 1.4357, val_acc: 0.4529,test_acc: 0.4640
# Epoch: 090, Loss: 1.0241,Train_acc: 0.6429, val_loss: 1.4371, val_acc: 0.4510,test_acc: 0.4678
# Epoch: 091, Loss: 1.0239,Train_acc: 0.6410, val_loss: 1.4358, val_acc: 0.4567,test_acc: 0.4678
# Epoch: 092, Loss: 1.0160,Train_acc: 0.6391, val_loss: 1.4460, val_acc: 0.4500,test_acc: 0.4621
# Epoch: 093, Loss: 1.0152,Train_acc: 0.6417, val_loss: 1.4509, val_acc: 0.4548,test_acc: 0.4669
# Epoch: 094, Loss: 1.0059,Train_acc: 0.6436, val_loss: 1.4477, val_acc: 0.4577,test_acc: 0.4688
# Epoch: 095, Loss: 1.0101,Train_acc: 0.6462, val_loss: 1.4561, val_acc: 0.4596,test_acc: 0.4678
# Epoch: 096, Loss: 1.0042,Train_acc: 0.6494, val_loss: 1.4557, val_acc: 0.4529,test_acc: 0.4630
# Epoch: 097, Loss: 1.0034,Train_acc: 0.6481, val_loss: 1.4396, val_acc: 0.4538,test_acc: 0.4697
# Epoch: 098, Loss: 1.0005,Train_acc: 0.6535, val_loss: 1.4530, val_acc: 0.4596,test_acc: 0.4688
# Epoch: 099, Loss: 0.9986,Train_acc: 0.6465, val_loss: 1.4431, val_acc: 0.4558,test_acc: 0.4707
# Epoch: 100, Loss: 0.9993,Train_acc: 0.6442, val_loss: 1.4563, val_acc: 0.4567,test_acc: 0.4611
# Epoch: 101, Loss: 0.9950,Train_acc: 0.6513, val_loss: 1.4317, val_acc: 0.4625,test_acc: 0.4621
# Epoch: 102, Loss: 0.9850,Train_acc: 0.6606, val_loss: 1.4384, val_acc: 0.4625,test_acc: 0.4726
# Epoch: 103, Loss: 0.9884,Train_acc: 0.6558, val_loss: 1.4375, val_acc: 0.4587,test_acc: 0.4726
# Epoch: 104, Loss: 0.9838,Train_acc: 0.6596, val_loss: 1.4531, val_acc: 0.4606,test_acc: 0.4726
# Epoch: 105, Loss: 0.9854,Train_acc: 0.6571, val_loss: 1.4567, val_acc: 0.4567,test_acc: 0.4688
# Epoch: 106, Loss: 0.9795,Train_acc: 0.6561, val_loss: 1.4474, val_acc: 0.4644,test_acc: 0.4745
# Epoch: 107, Loss: 0.9812,Train_acc: 0.6567, val_loss: 1.4515, val_acc: 0.4721,test_acc: 0.4630
# Epoch: 108, Loss: 0.9792,Train_acc: 0.6548, val_loss: 1.4490, val_acc: 0.4577,test_acc: 0.4649
# Epoch: 109, Loss: 0.9751,Train_acc: 0.6615, val_loss: 1.4674, val_acc: 0.4548,test_acc: 0.4726
# Epoch: 110, Loss: 0.9737,Train_acc: 0.6638, val_loss: 1.4708, val_acc: 0.4635,test_acc: 0.4765
# Epoch: 111, Loss: 0.9707,Train_acc: 0.6663, val_loss: 1.4455, val_acc: 0.4683,test_acc: 0.4736
# Epoch: 112, Loss: 0.9716,Train_acc: 0.6590, val_loss: 1.4466, val_acc: 0.4644,test_acc: 0.4688
# Epoch: 113, Loss: 0.9768,Train_acc: 0.6580, val_loss: 1.4610, val_acc: 0.4635,test_acc: 0.4726
# Epoch: 114, Loss: 0.9646,Train_acc: 0.6660, val_loss: 1.4613, val_acc: 0.4606,test_acc: 0.4717
# Epoch: 115, Loss: 0.9568,Train_acc: 0.6728, val_loss: 1.4468, val_acc: 0.4692,test_acc: 0.4774
# Epoch: 116, Loss: 0.9625,Train_acc: 0.6705, val_loss: 1.4675, val_acc: 0.4683,test_acc: 0.4745
# Epoch: 117, Loss: 0.9563,Train_acc: 0.6756, val_loss: 1.4490, val_acc: 0.4673,test_acc: 0.4745
# Epoch: 118, Loss: 0.9538,Train_acc: 0.6721, val_loss: 1.4728, val_acc: 0.4721,test_acc: 0.4765
# Epoch: 119, Loss: 0.9544,Train_acc: 0.6724, val_loss: 1.4793, val_acc: 0.4644,test_acc: 0.4717
# Epoch: 120, Loss: 0.9473,Train_acc: 0.6708, val_loss: 1.4617, val_acc: 0.4615,test_acc: 0.4765
# Epoch: 121, Loss: 0.9486,Train_acc: 0.6705, val_loss: 1.4298, val_acc: 0.4635,test_acc: 0.4774
# Epoch: 122, Loss: 0.9410,Train_acc: 0.6753, val_loss: 1.4617, val_acc: 0.4615,test_acc: 0.4774
# Epoch: 123, Loss: 0.9461,Train_acc: 0.6756, val_loss: 1.4604, val_acc: 0.4673,test_acc: 0.4793
# Epoch: 124, Loss: 0.9404,Train_acc: 0.6753, val_loss: 1.4647, val_acc: 0.4663,test_acc: 0.4697
# Epoch: 125, Loss: 0.9420,Train_acc: 0.6747, val_loss: 1.5089, val_acc: 0.4654,test_acc: 0.4745
# Epoch: 126, Loss: 0.9351,Train_acc: 0.6744, val_loss: 1.4449, val_acc: 0.4529,test_acc: 0.4774
# Epoch: 127, Loss: 0.9342,Train_acc: 0.6756, val_loss: 1.4898, val_acc: 0.4654,test_acc: 0.4745
# Epoch: 128, Loss: 0.9326,Train_acc: 0.6788, val_loss: 1.4770, val_acc: 0.4712,test_acc: 0.4793
# Epoch: 129, Loss: 0.9290,Train_acc: 0.6760, val_loss: 1.5045, val_acc: 0.4625,test_acc: 0.4765
# Epoch: 130, Loss: 0.9315,Train_acc: 0.6779, val_loss: 1.4768, val_acc: 0.4625,test_acc: 0.4726
# Epoch: 131, Loss: 0.9266,Train_acc: 0.6798, val_loss: 1.4721, val_acc: 0.4635,test_acc: 0.4755
# Epoch: 132, Loss: 0.9245,Train_acc: 0.6821, val_loss: 1.4771, val_acc: 0.4663,test_acc: 0.4813
# Epoch: 133, Loss: 0.9217,Train_acc: 0.6824, val_loss: 1.4833, val_acc: 0.4692,test_acc: 0.4774
# Epoch: 134, Loss: 0.9210,Train_acc: 0.6830, val_loss: 1.4640, val_acc: 0.4712,test_acc: 0.4803
# Epoch: 135, Loss: 0.9213,Train_acc: 0.6811, val_loss: 1.4762, val_acc: 0.4683,test_acc: 0.4774
# Epoch: 136, Loss: 0.9225,Train_acc: 0.6833, val_loss: 1.4709, val_acc: 0.4654,test_acc: 0.4784
# Epoch: 137, Loss: 0.9204,Train_acc: 0.6862, val_loss: 1.4679, val_acc: 0.4683,test_acc: 0.4803
# Epoch: 138, Loss: 0.9133,Train_acc: 0.6840, val_loss: 1.4886, val_acc: 0.4683,test_acc: 0.4793
# Epoch: 139, Loss: 0.9129,Train_acc: 0.6843, val_loss: 1.4636, val_acc: 0.4692,test_acc: 0.4784
# Epoch: 140, Loss: 0.9084,Train_acc: 0.6849, val_loss: 1.5019, val_acc: 0.4663,test_acc: 0.4784
# Epoch: 141, Loss: 0.9152,Train_acc: 0.6904, val_loss: 1.4793, val_acc: 0.4644,test_acc: 0.4765
# Epoch: 142, Loss: 0.9055,Train_acc: 0.6897, val_loss: 1.4761, val_acc: 0.4654,test_acc: 0.4736
# Epoch: 143, Loss: 0.9034,Train_acc: 0.6888, val_loss: 1.4588, val_acc: 0.4644,test_acc: 0.4793
# Epoch: 144, Loss: 0.9057,Train_acc: 0.6885, val_loss: 1.4675, val_acc: 0.4692,test_acc: 0.4765
# Epoch: 145, Loss: 0.9013,Train_acc: 0.6897, val_loss: 1.4715, val_acc: 0.4663,test_acc: 0.4803
# Epoch: 146, Loss: 0.9047,Train_acc: 0.6929, val_loss: 1.5164, val_acc: 0.4625,test_acc: 0.4793
# Epoch: 147, Loss: 0.8998,Train_acc: 0.6929, val_loss: 1.4923, val_acc: 0.4702,test_acc: 0.4726
# Epoch: 148, Loss: 0.8956,Train_acc: 0.6891, val_loss: 1.5022, val_acc: 0.4644,test_acc: 0.4793
# Epoch: 149, Loss: 0.8986,Train_acc: 0.6891, val_loss: 1.4853, val_acc: 0.4663,test_acc: 0.4793
# Epoch: 150, Loss: 0.8979,Train_acc: 0.6942, val_loss: 1.4945, val_acc: 0.4683,test_acc: 0.4813
# Epoch: 151, Loss: 0.8857,Train_acc: 0.6984, val_loss: 1.5072, val_acc: 0.4663,test_acc: 0.4765
# Epoch: 152, Loss: 0.8886,Train_acc: 0.6913, val_loss: 1.4881, val_acc: 0.4635,test_acc: 0.4755
# Epoch: 153, Loss: 0.8947,Train_acc: 0.6946, val_loss: 1.5157, val_acc: 0.4712,test_acc: 0.4841
# Epoch: 154, Loss: 0.8869,Train_acc: 0.6917, val_loss: 1.4712, val_acc: 0.4625,test_acc: 0.4841
# Epoch: 155, Loss: 0.8898,Train_acc: 0.6952, val_loss: 1.4973, val_acc: 0.4740,test_acc: 0.4890
# Epoch: 156, Loss: 0.8825,Train_acc: 0.6926, val_loss: 1.5002, val_acc: 0.4663,test_acc: 0.4717
# Epoch: 157, Loss: 0.8909,Train_acc: 0.6933, val_loss: 1.5137, val_acc: 0.4644,test_acc: 0.4803
# Epoch: 158, Loss: 0.8874,Train_acc: 0.6933, val_loss: 1.5110, val_acc: 0.4692,test_acc: 0.4890
# Epoch: 159, Loss: 0.8841,Train_acc: 0.6923, val_loss: 1.4971, val_acc: 0.4692,test_acc: 0.4861
# Epoch: 160, Loss: 0.8805,Train_acc: 0.6965, val_loss: 1.4959, val_acc: 0.4692,test_acc: 0.4784
# Epoch: 161, Loss: 0.8739,Train_acc: 0.6958, val_loss: 1.5212, val_acc: 0.4702,test_acc: 0.4784
# Epoch: 162, Loss: 0.8781,Train_acc: 0.7038, val_loss: 1.5142, val_acc: 0.4702,test_acc: 0.4774
# Epoch: 163, Loss: 0.8747,Train_acc: 0.6920, val_loss: 1.4951, val_acc: 0.4625,test_acc: 0.4774
# Epoch: 164, Loss: 0.8745,Train_acc: 0.6949, val_loss: 1.4914, val_acc: 0.4625,test_acc: 0.4832
# Epoch: 165, Loss: 0.8701,Train_acc: 0.6946, val_loss: 1.4992, val_acc: 0.4673,test_acc: 0.4813
# Epoch: 166, Loss: 0.8655,Train_acc: 0.7006, val_loss: 1.5036, val_acc: 0.4731,test_acc: 0.4899
# Epoch: 167, Loss: 0.8794,Train_acc: 0.6987, val_loss: 1.5229, val_acc: 0.4702,test_acc: 0.4813
# Epoch: 168, Loss: 0.8658,Train_acc: 0.6955, val_loss: 1.4935, val_acc: 0.4663,test_acc: 0.4841
# Epoch: 169, Loss: 0.8709,Train_acc: 0.6974, val_loss: 1.4937, val_acc: 0.4635,test_acc: 0.4832
# Epoch: 170, Loss: 0.8603,Train_acc: 0.7000, val_loss: 1.5135, val_acc: 0.4692,test_acc: 0.4861
# Epoch: 171, Loss: 0.8710,Train_acc: 0.7119, val_loss: 1.5442, val_acc: 0.4798,test_acc: 0.4880
# Epoch: 172, Loss: 0.8586,Train_acc: 0.6968, val_loss: 1.4871, val_acc: 0.4673,test_acc: 0.4813
# Epoch: 173, Loss: 0.8648,Train_acc: 0.7010, val_loss: 1.5219, val_acc: 0.4663,test_acc: 0.4822
# Epoch: 174, Loss: 0.8626,Train_acc: 0.7006, val_loss: 1.5250, val_acc: 0.4663,test_acc: 0.4870
# Epoch: 175, Loss: 0.8495,Train_acc: 0.6965, val_loss: 1.5138, val_acc: 0.4654,test_acc: 0.4745
# Epoch: 176, Loss: 0.8605,Train_acc: 0.7054, val_loss: 1.5194, val_acc: 0.4721,test_acc: 0.4880
# Epoch: 177, Loss: 0.8615,Train_acc: 0.7042, val_loss: 1.5266, val_acc: 0.4750,test_acc: 0.4832
# Epoch: 178, Loss: 0.8512,Train_acc: 0.7106, val_loss: 1.5190, val_acc: 0.4798,test_acc: 0.4822
# Epoch: 179, Loss: 0.8575,Train_acc: 0.7045, val_loss: 1.5120, val_acc: 0.4750,test_acc: 0.4813
# Epoch: 180, Loss: 0.8587,Train_acc: 0.7016, val_loss: 1.5023, val_acc: 0.4673,test_acc: 0.4793
# Epoch: 181, Loss: 0.8539,Train_acc: 0.7077, val_loss: 1.5434, val_acc: 0.4721,test_acc: 0.4870
# Epoch: 182, Loss: 0.8487,Train_acc: 0.7141, val_loss: 1.5042, val_acc: 0.4740,test_acc: 0.4909
# Epoch: 183, Loss: 0.8467,Train_acc: 0.7135, val_loss: 1.5218, val_acc: 0.4779,test_acc: 0.4870
# Epoch: 184, Loss: 0.8562,Train_acc: 0.7080, val_loss: 1.5468, val_acc: 0.4750,test_acc: 0.4899
# Epoch: 185, Loss: 0.8411,Train_acc: 0.7083, val_loss: 1.5407, val_acc: 0.4712,test_acc: 0.4909
# Epoch: 186, Loss: 0.8471,Train_acc: 0.7074, val_loss: 1.5179, val_acc: 0.4740,test_acc: 0.4890
# Epoch: 187, Loss: 0.8421,Train_acc: 0.7147, val_loss: 1.5397, val_acc: 0.4702,test_acc: 0.4841
# Epoch: 188, Loss: 0.8416,Train_acc: 0.7189, val_loss: 1.5470, val_acc: 0.4750,test_acc: 0.4918
# Epoch: 189, Loss: 0.8412,Train_acc: 0.7109, val_loss: 1.5289, val_acc: 0.4712,test_acc: 0.4890
# Epoch: 190, Loss: 0.8392,Train_acc: 0.7115, val_loss: 1.5359, val_acc: 0.4750,test_acc: 0.4841
# Epoch: 191, Loss: 0.8321,Train_acc: 0.7186, val_loss: 1.5209, val_acc: 0.4712,test_acc: 0.4880
# Epoch: 192, Loss: 0.8407,Train_acc: 0.7215, val_loss: 1.5405, val_acc: 0.4837,test_acc: 0.4841
# Epoch: 193, Loss: 0.8422,Train_acc: 0.7179, val_loss: 1.5079, val_acc: 0.4769,test_acc: 0.4841
# Epoch: 194, Loss: 0.8337,Train_acc: 0.7112, val_loss: 1.5231, val_acc: 0.4702,test_acc: 0.4870
# Epoch: 195, Loss: 0.8307,Train_acc: 0.7106, val_loss: 1.5464, val_acc: 0.4779,test_acc: 0.4861
# Epoch: 196, Loss: 0.8337,Train_acc: 0.7170, val_loss: 1.5082, val_acc: 0.4875,test_acc: 0.4870
# Epoch: 197, Loss: 0.8318,Train_acc: 0.7234, val_loss: 1.5251, val_acc: 0.4837,test_acc: 0.4890
# Epoch: 198, Loss: 0.8224,Train_acc: 0.7196, val_loss: 1.5036, val_acc: 0.4721,test_acc: 0.4832
# Epoch: 199, Loss: 0.8269,Train_acc: 0.7189, val_loss: 1.5323, val_acc: 0.4750,test_acc: 0.4822
# Epoch: 200, Loss: 0.8296,Train_acc: 0.7231, val_loss: 1.5434, val_acc: 0.4808,test_acc: 0.4890
# Epoch: 201, Loss: 0.8192,Train_acc: 0.7212, val_loss: 1.5332, val_acc: 0.4769,test_acc: 0.4909
# Epoch: 202, Loss: 0.8216,Train_acc: 0.7179, val_loss: 1.5522, val_acc: 0.4702,test_acc: 0.4890
# Epoch: 203, Loss: 0.8283,Train_acc: 0.7215, val_loss: 1.5683, val_acc: 0.4760,test_acc: 0.4861
# Epoch: 204, Loss: 0.8237,Train_acc: 0.7228, val_loss: 1.5551, val_acc: 0.4788,test_acc: 0.4861
# Epoch: 205, Loss: 0.8253,Train_acc: 0.7244, val_loss: 1.5343, val_acc: 0.4702,test_acc: 0.4870
# Epoch: 206, Loss: 0.8240,Train_acc: 0.7231, val_loss: 1.5244, val_acc: 0.4750,test_acc: 0.4890
# Epoch: 207, Loss: 0.8217,Train_acc: 0.7202, val_loss: 1.5536, val_acc: 0.4798,test_acc: 0.4822
# Epoch: 208, Loss: 0.8131,Train_acc: 0.7250, val_loss: 1.5869, val_acc: 0.4808,test_acc: 0.4909
# Epoch: 209, Loss: 0.8107,Train_acc: 0.7311, val_loss: 1.5704, val_acc: 0.4827,test_acc: 0.4918
# Epoch: 210, Loss: 0.8137,Train_acc: 0.7247, val_loss: 1.5372, val_acc: 0.4798,test_acc: 0.4890
# Epoch: 211, Loss: 0.8071,Train_acc: 0.7228, val_loss: 1.5470, val_acc: 0.4769,test_acc: 0.4870
# Epoch: 212, Loss: 0.8116,Train_acc: 0.7228, val_loss: 1.5514, val_acc: 0.4779,test_acc: 0.4957
# Epoch: 213, Loss: 0.8094,Train_acc: 0.7279, val_loss: 1.5519, val_acc: 0.4779,test_acc: 0.4909
# Epoch: 214, Loss: 0.8149,Train_acc: 0.7301, val_loss: 1.5773, val_acc: 0.4885,test_acc: 0.4890
# Epoch: 215, Loss: 0.8081,Train_acc: 0.7260, val_loss: 1.5280, val_acc: 0.4904,test_acc: 0.4947
# Epoch: 216, Loss: 0.8050,Train_acc: 0.7221, val_loss: 1.5393, val_acc: 0.4808,test_acc: 0.4947
# Epoch: 217, Loss: 0.8074,Train_acc: 0.7224, val_loss: 1.5533, val_acc: 0.4779,test_acc: 0.4870
# Epoch: 218, Loss: 0.8014,Train_acc: 0.7282, val_loss: 1.5470, val_acc: 0.4817,test_acc: 0.4851
# Epoch: 219, Loss: 0.8012,Train_acc: 0.7279, val_loss: 1.5373, val_acc: 0.4788,test_acc: 0.4890
# Epoch: 220, Loss: 0.8065,Train_acc: 0.7247, val_loss: 1.5406, val_acc: 0.4837,test_acc: 0.4976
# Epoch: 221, Loss: 0.7923,Train_acc: 0.7228, val_loss: 1.5376, val_acc: 0.4817,test_acc: 0.4938
# Epoch: 222, Loss: 0.7941,Train_acc: 0.7327, val_loss: 1.5513, val_acc: 0.4798,test_acc: 0.4909
# Epoch: 223, Loss: 0.7987,Train_acc: 0.7314, val_loss: 1.5391, val_acc: 0.4856,test_acc: 0.4880
# Epoch: 224, Loss: 0.8028,Train_acc: 0.7333, val_loss: 1.5563, val_acc: 0.4846,test_acc: 0.4899
# Epoch: 225, Loss: 0.7969,Train_acc: 0.7314, val_loss: 1.5525, val_acc: 0.4865,test_acc: 0.4957
# Epoch: 226, Loss: 0.7977,Train_acc: 0.7295, val_loss: 1.5265, val_acc: 0.4788,test_acc: 0.4928
# Epoch: 227, Loss: 0.7962,Train_acc: 0.7343, val_loss: 1.5912, val_acc: 0.4798,test_acc: 0.4928
# Epoch: 228, Loss: 0.7952,Train_acc: 0.7359, val_loss: 1.5927, val_acc: 0.4817,test_acc: 0.4928
# Epoch: 229, Loss: 0.7972,Train_acc: 0.7346, val_loss: 1.5529, val_acc: 0.4798,test_acc: 0.4832
# Epoch: 230, Loss: 0.7917,Train_acc: 0.7269, val_loss: 1.5579, val_acc: 0.4837,test_acc: 0.4870
# Epoch: 231, Loss: 0.7923,Train_acc: 0.7397, val_loss: 1.5756, val_acc: 0.4837,test_acc: 0.4918
# Epoch: 232, Loss: 0.7871,Train_acc: 0.7381, val_loss: 1.5416, val_acc: 0.4827,test_acc: 0.4986
# Epoch: 233, Loss: 0.7913,Train_acc: 0.7356, val_loss: 1.5712, val_acc: 0.4846,test_acc: 0.4957
# Epoch: 234, Loss: 0.7936,Train_acc: 0.7314, val_loss: 1.5982, val_acc: 0.4788,test_acc: 0.4890
# Epoch: 235, Loss: 0.7896,Train_acc: 0.7333, val_loss: 1.5577, val_acc: 0.4837,test_acc: 0.4890
# Epoch: 236, Loss: 0.7889,Train_acc: 0.7401, val_loss: 1.5388, val_acc: 0.4798,test_acc: 0.4957
# Epoch: 237, Loss: 0.7820,Train_acc: 0.7369, val_loss: 1.5556, val_acc: 0.4875,test_acc: 0.4966
# Epoch: 238, Loss: 0.7846,Train_acc: 0.7353, val_loss: 1.5716, val_acc: 0.4875,test_acc: 0.4966
# Epoch: 239, Loss: 0.7826,Train_acc: 0.7333, val_loss: 1.5523, val_acc: 0.4779,test_acc: 0.4918
# Epoch: 240, Loss: 0.7857,Train_acc: 0.7343, val_loss: 1.5588, val_acc: 0.4817,test_acc: 0.4851
# Epoch: 241, Loss: 0.7809,Train_acc: 0.7397, val_loss: 1.5928, val_acc: 0.4952,test_acc: 0.5005
# Epoch: 242, Loss: 0.7801,Train_acc: 0.7449, val_loss: 1.6087, val_acc: 0.4885,test_acc: 0.5024
# Epoch: 243, Loss: 0.7792,Train_acc: 0.7417, val_loss: 1.5682, val_acc: 0.4894,test_acc: 0.4957
# Epoch: 244, Loss: 0.7785,Train_acc: 0.7362, val_loss: 1.5571, val_acc: 0.4817,test_acc: 0.4938
# Epoch: 245, Loss: 0.7648,Train_acc: 0.7420, val_loss: 1.5817, val_acc: 0.4885,test_acc: 0.4928
# Epoch: 246, Loss: 0.7741,Train_acc: 0.7426, val_loss: 1.5768, val_acc: 0.4817,test_acc: 0.4918
# Epoch: 247, Loss: 0.7709,Train_acc: 0.7385, val_loss: 1.5858, val_acc: 0.4827,test_acc: 0.4947
# Epoch: 248, Loss: 0.7719,Train_acc: 0.7401, val_loss: 1.5675, val_acc: 0.4798,test_acc: 0.4928
# Epoch: 249, Loss: 0.7757,Train_acc: 0.7417, val_loss: 1.5913, val_acc: 0.4865,test_acc: 0.4918
# Epoch: 250, Loss: 0.7750,Train_acc: 0.7471, val_loss: 1.5888, val_acc: 0.4846,test_acc: 0.4947
# Epoch: 251, Loss: 0.7683,Train_acc: 0.7417, val_loss: 1.5910, val_acc: 0.4856,test_acc: 0.4909
# Epoch: 252, Loss: 0.7708,Train_acc: 0.7426, val_loss: 1.5963, val_acc: 0.4808,test_acc: 0.4928
# Epoch: 253, Loss: 0.7647,Train_acc: 0.7410, val_loss: 1.5924, val_acc: 0.4904,test_acc: 0.4947
# Epoch: 254, Loss: 0.7638,Train_acc: 0.7478, val_loss: 1.5916, val_acc: 0.4913,test_acc: 0.4938
# Epoch: 255, Loss: 0.7660,Train_acc: 0.7481, val_loss: 1.6009, val_acc: 0.4923,test_acc: 0.4995
# Epoch: 256, Loss: 0.7617,Train_acc: 0.7484, val_loss: 1.5805, val_acc: 0.4923,test_acc: 0.4995
# Epoch: 257, Loss: 0.7640,Train_acc: 0.7458, val_loss: 1.5788, val_acc: 0.4856,test_acc: 0.4995
# Epoch: 258, Loss: 0.7634,Train_acc: 0.7474, val_loss: 1.6086, val_acc: 0.4962,test_acc: 0.5014
# Epoch: 259, Loss: 0.7665,Train_acc: 0.7519, val_loss: 1.5820, val_acc: 0.4990,test_acc: 0.5005
# Epoch: 260, Loss: 0.7622,Train_acc: 0.7506, val_loss: 1.5741, val_acc: 0.4981,test_acc: 0.5024
# Epoch: 261, Loss: 0.7593,Train_acc: 0.7436, val_loss: 1.6004, val_acc: 0.4942,test_acc: 0.5005
# Epoch: 262, Loss: 0.7668,Train_acc: 0.7433, val_loss: 1.5976, val_acc: 0.4952,test_acc: 0.4957
# Epoch: 263, Loss: 0.7588,Train_acc: 0.7449, val_loss: 1.5694, val_acc: 0.4923,test_acc: 0.4947
# Epoch: 264, Loss: 0.7673,Train_acc: 0.7458, val_loss: 1.6232, val_acc: 0.4933,test_acc: 0.4947
# Epoch: 265, Loss: 0.7522,Train_acc: 0.7455, val_loss: 1.6099, val_acc: 0.4904,test_acc: 0.4918
# Epoch: 266, Loss: 0.7600,Train_acc: 0.7484, val_loss: 1.6111, val_acc: 0.4913,test_acc: 0.4870
# Epoch: 267, Loss: 0.7512,Train_acc: 0.7452, val_loss: 1.5962, val_acc: 0.4933,test_acc: 0.4890
# Epoch: 268, Loss: 0.7623,Train_acc: 0.7458, val_loss: 1.5652, val_acc: 0.4904,test_acc: 0.4966
# Epoch: 269, Loss: 0.7624,Train_acc: 0.7462, val_loss: 1.6074, val_acc: 0.4885,test_acc: 0.4909
# Epoch: 270, Loss: 0.7607,Train_acc: 0.7506, val_loss: 1.6057, val_acc: 0.4942,test_acc: 0.4870
# Epoch: 271, Loss: 0.7551,Train_acc: 0.7497, val_loss: 1.5811, val_acc: 0.4971,test_acc: 0.4909
# Epoch: 272, Loss: 0.7513,Train_acc: 0.7417, val_loss: 1.6038, val_acc: 0.4846,test_acc: 0.4899
# Epoch: 273, Loss: 0.7534,Train_acc: 0.7481, val_loss: 1.6271, val_acc: 0.4875,test_acc: 0.4986
# Epoch: 274, Loss: 0.7553,Train_acc: 0.7516, val_loss: 1.6270, val_acc: 0.4933,test_acc: 0.5014
# Epoch: 275, Loss: 0.7573,Train_acc: 0.7542, val_loss: 1.5805, val_acc: 0.4962,test_acc: 0.5024
# Epoch: 276, Loss: 0.7512,Train_acc: 0.7436, val_loss: 1.6057, val_acc: 0.4913,test_acc: 0.4918
# Epoch: 277, Loss: 0.7546,Train_acc: 0.7439, val_loss: 1.5897, val_acc: 0.4894,test_acc: 0.4947
# Epoch: 278, Loss: 0.7562,Train_acc: 0.7548, val_loss: 1.6104, val_acc: 0.4952,test_acc: 0.5053
# Epoch: 279, Loss: 0.7559,Train_acc: 0.7529, val_loss: 1.5885, val_acc: 0.4942,test_acc: 0.4995
# Epoch: 280, Loss: 0.7408,Train_acc: 0.7506, val_loss: 1.6048, val_acc: 0.4913,test_acc: 0.4947
# Epoch: 281, Loss: 0.7444,Train_acc: 0.7484, val_loss: 1.6006, val_acc: 0.4904,test_acc: 0.4938
# Epoch: 282, Loss: 0.7464,Train_acc: 0.7535, val_loss: 1.6352, val_acc: 0.4933,test_acc: 0.4966
# Epoch: 283, Loss: 0.7452,Train_acc: 0.7545, val_loss: 1.5744, val_acc: 0.5010,test_acc: 0.4986
# Epoch: 284, Loss: 0.7440,Train_acc: 0.7606, val_loss: 1.6085, val_acc: 0.4981,test_acc: 0.5139
# Epoch: 285, Loss: 0.7398,Train_acc: 0.7583, val_loss: 1.6172, val_acc: 0.4990,test_acc: 0.5005
# Epoch: 286, Loss: 0.7446,Train_acc: 0.7500, val_loss: 1.6026, val_acc: 0.4865,test_acc: 0.4957
# Epoch: 287, Loss: 0.7471,Train_acc: 0.7558, val_loss: 1.6432, val_acc: 0.4913,test_acc: 0.5024
# Epoch: 288, Loss: 0.7370,Train_acc: 0.7619, val_loss: 1.6466, val_acc: 0.4981,test_acc: 0.5139
# Epoch: 289, Loss: 0.7422,Train_acc: 0.7587, val_loss: 1.6254, val_acc: 0.4894,test_acc: 0.5053
# Epoch: 290, Loss: 0.7423,Train_acc: 0.7535, val_loss: 1.6602, val_acc: 0.4894,test_acc: 0.5043
# Epoch: 291, Loss: 0.7428,Train_acc: 0.7513, val_loss: 1.6245, val_acc: 0.4865,test_acc: 0.5014
# Epoch: 292, Loss: 0.7425,Train_acc: 0.7577, val_loss: 1.6223, val_acc: 0.4962,test_acc: 0.5072
# Epoch: 293, Loss: 0.7360,Train_acc: 0.7587, val_loss: 1.6404, val_acc: 0.4962,test_acc: 0.5130
# Epoch: 294, Loss: 0.7364,Train_acc: 0.7571, val_loss: 1.6687, val_acc: 0.5000,test_acc: 0.5034
# Epoch: 295, Loss: 0.7316,Train_acc: 0.7577, val_loss: 1.5978, val_acc: 0.4923,test_acc: 0.5014
# Epoch: 296, Loss: 0.7346,Train_acc: 0.7574, val_loss: 1.6619, val_acc: 0.4971,test_acc: 0.5043
# Epoch: 297, Loss: 0.7275,Train_acc: 0.7580, val_loss: 1.6149, val_acc: 0.4971,test_acc: 0.5005
# Epoch: 298, Loss: 0.7334,Train_acc: 0.7583, val_loss: 1.6525, val_acc: 0.4933,test_acc: 0.5005
# Epoch: 299, Loss: 0.7298,Train_acc: 0.7599, val_loss: 1.5929, val_acc: 0.4942,test_acc: 0.5082
# Epoch: 300, Loss: 0.7361,Train_acc: 0.7635, val_loss: 1.6397, val_acc: 0.4962,test_acc: 0.5130
# Epoch: 301, Loss: 0.7307,Train_acc: 0.7590, val_loss: 1.5907, val_acc: 0.4962,test_acc: 0.5072
# Epoch: 302, Loss: 0.7275,Train_acc: 0.7622, val_loss: 1.6499, val_acc: 0.5010,test_acc: 0.5014
# Epoch: 303, Loss: 0.7244,Train_acc: 0.7593, val_loss: 1.5967, val_acc: 0.4904,test_acc: 0.5043
# Epoch: 304, Loss: 0.7310,Train_acc: 0.7641, val_loss: 1.6422, val_acc: 0.4962,test_acc: 0.5082
# Epoch: 305, Loss: 0.7243,Train_acc: 0.7638, val_loss: 1.6252, val_acc: 0.4942,test_acc: 0.5062
# Epoch: 306, Loss: 0.7320,Train_acc: 0.7606, val_loss: 1.6564, val_acc: 0.4981,test_acc: 0.5043
# Epoch: 307, Loss: 0.7248,Train_acc: 0.7631, val_loss: 1.6226, val_acc: 0.5019,test_acc: 0.5072
# Epoch: 308, Loss: 0.7259,Train_acc: 0.7635, val_loss: 1.6194, val_acc: 0.5010,test_acc: 0.5082
# Epoch: 309, Loss: 0.7248,Train_acc: 0.7638, val_loss: 1.6488, val_acc: 0.4923,test_acc: 0.5062
# Epoch: 310, Loss: 0.7295,Train_acc: 0.7635, val_loss: 1.6653, val_acc: 0.4971,test_acc: 0.5091
# Epoch: 311, Loss: 0.7181,Train_acc: 0.7609, val_loss: 1.6645, val_acc: 0.4971,test_acc: 0.5043
# Epoch: 312, Loss: 0.7149,Train_acc: 0.7644, val_loss: 1.6313, val_acc: 0.5000,test_acc: 0.5043
# Epoch: 313, Loss: 0.7255,Train_acc: 0.7596, val_loss: 1.6417, val_acc: 0.5000,test_acc: 0.5043
# Epoch: 314, Loss: 0.7170,Train_acc: 0.7641, val_loss: 1.6775, val_acc: 0.4981,test_acc: 0.5034
# Epoch: 315, Loss: 0.7162,Train_acc: 0.7625, val_loss: 1.6264, val_acc: 0.4971,test_acc: 0.5014
# Epoch: 316, Loss: 0.7226,Train_acc: 0.7615, val_loss: 1.6787, val_acc: 0.4981,test_acc: 0.5024
# Epoch: 317, Loss: 0.7226,Train_acc: 0.7625, val_loss: 1.6896, val_acc: 0.5010,test_acc: 0.5014
# Epoch: 318, Loss: 0.7204,Train_acc: 0.7587, val_loss: 1.6554, val_acc: 0.4990,test_acc: 0.4986
# Epoch: 319, Loss: 0.7190,Train_acc: 0.7625, val_loss: 1.6616, val_acc: 0.4933,test_acc: 0.5014
# Epoch: 320, Loss: 0.7206,Train_acc: 0.7603, val_loss: 1.6502, val_acc: 0.5029,test_acc: 0.5034
# Epoch: 321, Loss: 0.7136,Train_acc: 0.7654, val_loss: 1.6614, val_acc: 0.5048,test_acc: 0.5005
# Epoch: 322, Loss: 0.7184,Train_acc: 0.7699, val_loss: 1.6662, val_acc: 0.5010,test_acc: 0.5062
# Epoch: 323, Loss: 0.7149,Train_acc: 0.7692, val_loss: 1.6306, val_acc: 0.5077,test_acc: 0.5053
# Epoch: 324, Loss: 0.7186,Train_acc: 0.7718, val_loss: 1.6200, val_acc: 0.5087,test_acc: 0.5168
# Epoch: 325, Loss: 0.7089,Train_acc: 0.7708, val_loss: 1.6407, val_acc: 0.4981,test_acc: 0.5187
# Epoch: 326, Loss: 0.7154,Train_acc: 0.7670, val_loss: 1.6198, val_acc: 0.5038,test_acc: 0.5053
# Epoch: 327, Loss: 0.7187,Train_acc: 0.7673, val_loss: 1.6481, val_acc: 0.5010,test_acc: 0.5110
# Epoch: 328, Loss: 0.7150,Train_acc: 0.7657, val_loss: 1.6500, val_acc: 0.5029,test_acc: 0.5101
# Epoch: 329, Loss: 0.7175,Train_acc: 0.7667, val_loss: 1.6965, val_acc: 0.5010,test_acc: 0.5072
# Epoch: 330, Loss: 0.7139,Train_acc: 0.7683, val_loss: 1.6822, val_acc: 0.4971,test_acc: 0.5053
# Epoch: 331, Loss: 0.7072,Train_acc: 0.7651, val_loss: 1.6580, val_acc: 0.4971,test_acc: 0.5034
# Epoch: 332, Loss: 0.7103,Train_acc: 0.7667, val_loss: 1.6439, val_acc: 0.4990,test_acc: 0.5024
# Epoch: 333, Loss: 0.7102,Train_acc: 0.7679, val_loss: 1.6691, val_acc: 0.5019,test_acc: 0.5024
# Epoch: 334, Loss: 0.7057,Train_acc: 0.7721, val_loss: 1.6520, val_acc: 0.4981,test_acc: 0.4986
# Epoch: 335, Loss: 0.7022,Train_acc: 0.7715, val_loss: 1.6504, val_acc: 0.4981,test_acc: 0.5043
# Epoch: 336, Loss: 0.7090,Train_acc: 0.7663, val_loss: 1.6455, val_acc: 0.5000,test_acc: 0.5062
# Epoch: 337, Loss: 0.7128,Train_acc: 0.7702, val_loss: 1.6558, val_acc: 0.5067,test_acc: 0.5034
# Epoch: 338, Loss: 0.7112,Train_acc: 0.7763, val_loss: 1.6656, val_acc: 0.5077,test_acc: 0.5091
# Epoch: 339, Loss: 0.7022,Train_acc: 0.7718, val_loss: 1.6736, val_acc: 0.5038,test_acc: 0.4986
# Epoch: 340, Loss: 0.7091,Train_acc: 0.7647, val_loss: 1.6562, val_acc: 0.5010,test_acc: 0.5120
# Epoch: 341, Loss: 0.7066,Train_acc: 0.7696, val_loss: 1.6840, val_acc: 0.4962,test_acc: 0.5082
# Epoch: 342, Loss: 0.7009,Train_acc: 0.7686, val_loss: 1.6814, val_acc: 0.5038,test_acc: 0.4966
# Epoch: 343, Loss: 0.7004,Train_acc: 0.7731, val_loss: 1.6865, val_acc: 0.5087,test_acc: 0.5101
# Epoch: 344, Loss: 0.7046,Train_acc: 0.7667, val_loss: 1.6466, val_acc: 0.5019,test_acc: 0.5014
# Epoch: 345, Loss: 0.7109,Train_acc: 0.7705, val_loss: 1.6382, val_acc: 0.4981,test_acc: 0.5043
# Epoch: 346, Loss: 0.7088,Train_acc: 0.7728, val_loss: 1.6995, val_acc: 0.5048,test_acc: 0.5139
# Epoch: 347, Loss: 0.7073,Train_acc: 0.7795, val_loss: 1.6317, val_acc: 0.5144,test_acc: 0.5168
# Epoch: 348, Loss: 0.6925,Train_acc: 0.7772, val_loss: 1.6804, val_acc: 0.5106,test_acc: 0.5130
# Epoch: 349, Loss: 0.6983,Train_acc: 0.7747, val_loss: 1.6631, val_acc: 0.5077,test_acc: 0.5062
# Epoch: 350, Loss: 0.7001,Train_acc: 0.7689, val_loss: 1.7236, val_acc: 0.5058,test_acc: 0.5178
# Epoch: 351, Loss: 0.7034,Train_acc: 0.7724, val_loss: 1.6885, val_acc: 0.5067,test_acc: 0.5149
# Epoch: 352, Loss: 0.6999,Train_acc: 0.7782, val_loss: 1.6428, val_acc: 0.5038,test_acc: 0.5149
# Epoch: 353, Loss: 0.6977,Train_acc: 0.7792, val_loss: 1.6583, val_acc: 0.5067,test_acc: 0.5120
# Epoch: 354, Loss: 0.7012,Train_acc: 0.7686, val_loss: 1.6482, val_acc: 0.5000,test_acc: 0.5053
# Epoch: 355, Loss: 0.7040,Train_acc: 0.7705, val_loss: 1.6584, val_acc: 0.5019,test_acc: 0.5101
# Epoch: 356, Loss: 0.6948,Train_acc: 0.7753, val_loss: 1.6870, val_acc: 0.5067,test_acc: 0.5072
# Epoch: 357, Loss: 0.6959,Train_acc: 0.7865, val_loss: 1.7121, val_acc: 0.5125,test_acc: 0.5168
# Epoch: 358, Loss: 0.6971,Train_acc: 0.7808, val_loss: 1.7039, val_acc: 0.5144,test_acc: 0.5101
# Epoch: 359, Loss: 0.6935,Train_acc: 0.7718, val_loss: 1.6658, val_acc: 0.5038,test_acc: 0.5024
# Epoch: 360, Loss: 0.6931,Train_acc: 0.7734, val_loss: 1.6904, val_acc: 0.5058,test_acc: 0.5034
# Epoch: 361, Loss: 0.6906,Train_acc: 0.7827, val_loss: 1.6928, val_acc: 0.5067,test_acc: 0.5082
# Epoch: 362, Loss: 0.6952,Train_acc: 0.7833, val_loss: 1.6894, val_acc: 0.5163,test_acc: 0.5159
# Epoch: 363, Loss: 0.6975,Train_acc: 0.7792, val_loss: 1.6882, val_acc: 0.5154,test_acc: 0.5149
# Epoch: 364, Loss: 0.6915,Train_acc: 0.7696, val_loss: 1.6529, val_acc: 0.5077,test_acc: 0.5130
# Epoch: 365, Loss: 0.6875,Train_acc: 0.7712, val_loss: 1.6997, val_acc: 0.5077,test_acc: 0.5053
# Epoch: 366, Loss: 0.6904,Train_acc: 0.7811, val_loss: 1.6792, val_acc: 0.5163,test_acc: 0.5091
# Epoch: 367, Loss: 0.6878,Train_acc: 0.7840, val_loss: 1.6768, val_acc: 0.5096,test_acc: 0.5168
# Epoch: 368, Loss: 0.6881,Train_acc: 0.7769, val_loss: 1.6998, val_acc: 0.5115,test_acc: 0.5091
# Epoch: 369, Loss: 0.6837,Train_acc: 0.7753, val_loss: 1.6567, val_acc: 0.5087,test_acc: 0.5062
# Epoch: 370, Loss: 0.6785,Train_acc: 0.7750, val_loss: 1.6847, val_acc: 0.5048,test_acc: 0.5053
# Epoch: 371, Loss: 0.6970,Train_acc: 0.7801, val_loss: 1.6869, val_acc: 0.5067,test_acc: 0.5082
# Epoch: 372, Loss: 0.6877,Train_acc: 0.7830, val_loss: 1.6736, val_acc: 0.5048,test_acc: 0.5120
# Epoch: 373, Loss: 0.6893,Train_acc: 0.7785, val_loss: 1.6597, val_acc: 0.5029,test_acc: 0.5072
# Epoch: 374, Loss: 0.6936,Train_acc: 0.7731, val_loss: 1.6727, val_acc: 0.5048,test_acc: 0.5062
# Epoch: 375, Loss: 0.6861,Train_acc: 0.7785, val_loss: 1.6779, val_acc: 0.5125,test_acc: 0.5101
# Epoch: 376, Loss: 0.6813,Train_acc: 0.7881, val_loss: 1.6662, val_acc: 0.5125,test_acc: 0.5187
# Epoch: 377, Loss: 0.6790,Train_acc: 0.7869, val_loss: 1.6770, val_acc: 0.5144,test_acc: 0.5197
# Epoch: 378, Loss: 0.6847,Train_acc: 0.7760, val_loss: 1.6697, val_acc: 0.5067,test_acc: 0.5149
# Epoch: 379, Loss: 0.6838,Train_acc: 0.7779, val_loss: 1.6967, val_acc: 0.5096,test_acc: 0.5101
# Epoch: 380, Loss: 0.6865,Train_acc: 0.7840, val_loss: 1.6942, val_acc: 0.5096,test_acc: 0.5101
# Epoch: 381, Loss: 0.6831,Train_acc: 0.7907, val_loss: 1.7209, val_acc: 0.5183,test_acc: 0.5187
# Epoch: 382, Loss: 0.6808,Train_acc: 0.7821, val_loss: 1.6909, val_acc: 0.5125,test_acc: 0.5120
# Epoch: 383, Loss: 0.6785,Train_acc: 0.7792, val_loss: 1.7252, val_acc: 0.5010,test_acc: 0.5082
# Epoch: 384, Loss: 0.6785,Train_acc: 0.7792, val_loss: 1.7251, val_acc: 0.5067,test_acc: 0.5110
# Epoch: 385, Loss: 0.6769,Train_acc: 0.7779, val_loss: 1.7091, val_acc: 0.5077,test_acc: 0.5072
# Epoch: 386, Loss: 0.6787,Train_acc: 0.7846, val_loss: 1.7095, val_acc: 0.5154,test_acc: 0.5178
# Epoch: 387, Loss: 0.6793,Train_acc: 0.7798, val_loss: 1.6948, val_acc: 0.5115,test_acc: 0.5178
# Epoch: 388, Loss: 0.6701,Train_acc: 0.7779, val_loss: 1.6862, val_acc: 0.5067,test_acc: 0.5120
# Epoch: 389, Loss: 0.6843,Train_acc: 0.7788, val_loss: 1.6922, val_acc: 0.5048,test_acc: 0.5072
# Epoch: 390, Loss: 0.6765,Train_acc: 0.7878, val_loss: 1.6788, val_acc: 0.5115,test_acc: 0.5178
# Epoch: 391, Loss: 0.6790,Train_acc: 0.7779, val_loss: 1.7099, val_acc: 0.5067,test_acc: 0.5139
# Epoch: 392, Loss: 0.6751,Train_acc: 0.7769, val_loss: 1.6808, val_acc: 0.5077,test_acc: 0.5101
# Epoch: 393, Loss: 0.6758,Train_acc: 0.7846, val_loss: 1.7313, val_acc: 0.5058,test_acc: 0.5120
# Epoch: 394, Loss: 0.6732,Train_acc: 0.7878, val_loss: 1.6914, val_acc: 0.5077,test_acc: 0.5082
# Epoch: 395, Loss: 0.6759,Train_acc: 0.7821, val_loss: 1.7096, val_acc: 0.5212,test_acc: 0.5082
# Epoch: 396, Loss: 0.6700,Train_acc: 0.7769, val_loss: 1.6880, val_acc: 0.5077,test_acc: 0.4976
# Epoch: 397, Loss: 0.6763,Train_acc: 0.7840, val_loss: 1.6917, val_acc: 0.5106,test_acc: 0.5072
# Epoch: 398, Loss: 0.6708,Train_acc: 0.7894, val_loss: 1.7239, val_acc: 0.5019,test_acc: 0.5197
# Epoch: 399, Loss: 0.6723,Train_acc: 0.7923, val_loss: 1.7124, val_acc: 0.5183,test_acc: 0.5255
# Epoch: 400, Loss: 0.6775,Train_acc: 0.7865, val_loss: 1.7116, val_acc: 0.5192,test_acc: 0.5139
# Epoch: 401, Loss: 0.6798,Train_acc: 0.7772, val_loss: 1.6725, val_acc: 0.5067,test_acc: 0.5034
# Epoch: 402, Loss: 0.6762,Train_acc: 0.7881, val_loss: 1.7226, val_acc: 0.5096,test_acc: 0.5168
# Epoch: 403, Loss: 0.6679,Train_acc: 0.7920, val_loss: 1.7342, val_acc: 0.5087,test_acc: 0.5255
# Epoch: 404, Loss: 0.6642,Train_acc: 0.7901, val_loss: 1.7229, val_acc: 0.5202,test_acc: 0.5283
# Epoch: 405, Loss: 0.6759,Train_acc: 0.7821, val_loss: 1.6718, val_acc: 0.5096,test_acc: 0.5024
# Epoch: 406, Loss: 0.6707,Train_acc: 0.7853, val_loss: 1.7049, val_acc: 0.5135,test_acc: 0.5110
# Epoch: 407, Loss: 0.6767,Train_acc: 0.7856, val_loss: 1.7164, val_acc: 0.5183,test_acc: 0.5110
# Epoch: 408, Loss: 0.6738,Train_acc: 0.7888, val_loss: 1.7192, val_acc: 0.5154,test_acc: 0.5207
# Epoch: 409, Loss: 0.6696,Train_acc: 0.7897, val_loss: 1.6686, val_acc: 0.5144,test_acc: 0.5139
# Epoch: 410, Loss: 0.6724,Train_acc: 0.7926, val_loss: 1.7280, val_acc: 0.5154,test_acc: 0.5178
# Epoch: 411, Loss: 0.6676,Train_acc: 0.7923, val_loss: 1.6866, val_acc: 0.5192,test_acc: 0.5110
# Epoch: 412, Loss: 0.6715,Train_acc: 0.7853, val_loss: 1.7532, val_acc: 0.5183,test_acc: 0.5091
# Epoch: 413, Loss: 0.6624,Train_acc: 0.7827, val_loss: 1.6936, val_acc: 0.5106,test_acc: 0.5149
# Epoch: 414, Loss: 0.6680,Train_acc: 0.7856, val_loss: 1.7371, val_acc: 0.5115,test_acc: 0.5120
# Epoch: 415, Loss: 0.6539,Train_acc: 0.7875, val_loss: 1.6965, val_acc: 0.5067,test_acc: 0.5101
# Epoch: 416, Loss: 0.6624,Train_acc: 0.7846, val_loss: 1.7112, val_acc: 0.5077,test_acc: 0.5091
# Epoch: 417, Loss: 0.6638,Train_acc: 0.7856, val_loss: 1.7430, val_acc: 0.5144,test_acc: 0.5082
# Epoch: 418, Loss: 0.6590,Train_acc: 0.7859, val_loss: 1.7612, val_acc: 0.5125,test_acc: 0.5207
# Epoch: 419, Loss: 0.6744,Train_acc: 0.7904, val_loss: 1.7474, val_acc: 0.5125,test_acc: 0.5255
# Epoch: 420, Loss: 0.6596,Train_acc: 0.7846, val_loss: 1.7420, val_acc: 0.5067,test_acc: 0.5053
# Epoch: 421, Loss: 0.6579,Train_acc: 0.7833, val_loss: 1.7108, val_acc: 0.5106,test_acc: 0.5062
# Epoch: 422, Loss: 0.6742,Train_acc: 0.7888, val_loss: 1.7209, val_acc: 0.5144,test_acc: 0.5159
# Epoch: 423, Loss: 0.6592,Train_acc: 0.7872, val_loss: 1.7283, val_acc: 0.5163,test_acc: 0.5216
# Epoch: 424, Loss: 0.6652,Train_acc: 0.7907, val_loss: 1.7179, val_acc: 0.5106,test_acc: 0.5178
# Epoch: 425, Loss: 0.6624,Train_acc: 0.7869, val_loss: 1.6679, val_acc: 0.5106,test_acc: 0.5072
# Epoch: 426, Loss: 0.6617,Train_acc: 0.7785, val_loss: 1.7236, val_acc: 0.5106,test_acc: 0.5034
# Epoch: 427, Loss: 0.6659,Train_acc: 0.7885, val_loss: 1.7155, val_acc: 0.5202,test_acc: 0.5072
# Epoch: 428, Loss: 0.6586,Train_acc: 0.7923, val_loss: 1.7243, val_acc: 0.5163,test_acc: 0.5159
# Epoch: 429, Loss: 0.6576,Train_acc: 0.7904, val_loss: 1.7547, val_acc: 0.5202,test_acc: 0.5178
# Epoch: 430, Loss: 0.6562,Train_acc: 0.7907, val_loss: 1.7003, val_acc: 0.5115,test_acc: 0.5139
# Epoch: 431, Loss: 0.6583,Train_acc: 0.7894, val_loss: 1.6841, val_acc: 0.5144,test_acc: 0.5062
# Epoch: 432, Loss: 0.6600,Train_acc: 0.7965, val_loss: 1.7536, val_acc: 0.5212,test_acc: 0.5245
# Epoch: 433, Loss: 0.6561,Train_acc: 0.7881, val_loss: 1.7247, val_acc: 0.5144,test_acc: 0.5159
# Epoch: 434, Loss: 0.6636,Train_acc: 0.7907, val_loss: 1.7294, val_acc: 0.5135,test_acc: 0.5130
# Epoch: 435, Loss: 0.6602,Train_acc: 0.7904, val_loss: 1.7736, val_acc: 0.5192,test_acc: 0.5062
# Epoch: 436, Loss: 0.6509,Train_acc: 0.7929, val_loss: 1.7268, val_acc: 0.5154,test_acc: 0.5159
# Epoch: 437, Loss: 0.6632,Train_acc: 0.7974, val_loss: 1.7326, val_acc: 0.5163,test_acc: 0.5216
# Epoch: 438, Loss: 0.6507,Train_acc: 0.7949, val_loss: 1.7274, val_acc: 0.5144,test_acc: 0.5159
# Epoch: 439, Loss: 0.6515,Train_acc: 0.7907, val_loss: 1.7434, val_acc: 0.5106,test_acc: 0.5091
# Epoch: 440, Loss: 0.6509,Train_acc: 0.7917, val_loss: 1.7688, val_acc: 0.5096,test_acc: 0.5110
# Epoch: 441, Loss: 0.6482,Train_acc: 0.8032, val_loss: 1.7133, val_acc: 0.5212,test_acc: 0.5226
# Epoch: 442, Loss: 0.6535,Train_acc: 0.8035, val_loss: 1.7424, val_acc: 0.5212,test_acc: 0.5255
# Epoch: 443, Loss: 0.6488,Train_acc: 0.7942, val_loss: 1.7254, val_acc: 0.5163,test_acc: 0.5101
# Epoch: 444, Loss: 0.6457,Train_acc: 0.7929, val_loss: 1.7352, val_acc: 0.5125,test_acc: 0.5101
# Epoch: 445, Loss: 0.6600,Train_acc: 0.7958, val_loss: 1.7143, val_acc: 0.5144,test_acc: 0.5149
# Epoch: 446, Loss: 0.6451,Train_acc: 0.7968, val_loss: 1.7632, val_acc: 0.5154,test_acc: 0.5120
# Epoch: 447, Loss: 0.6446,Train_acc: 0.7933, val_loss: 1.7509, val_acc: 0.5087,test_acc: 0.5082
# Epoch: 448, Loss: 0.6466,Train_acc: 0.7907, val_loss: 1.7262, val_acc: 0.5048,test_acc: 0.5159
# Epoch: 449, Loss: 0.6592,Train_acc: 0.8048, val_loss: 1.7550, val_acc: 0.5125,test_acc: 0.5245
# Epoch: 450, Loss: 0.6496,Train_acc: 0.8080, val_loss: 1.7784, val_acc: 0.5260,test_acc: 0.5283
# Epoch: 451, Loss: 0.6546,Train_acc: 0.7994, val_loss: 1.7346, val_acc: 0.5192,test_acc: 0.5187
# Epoch: 452, Loss: 0.6435,Train_acc: 0.7917, val_loss: 1.7193, val_acc: 0.5077,test_acc: 0.5139
# Epoch: 453, Loss: 0.6524,Train_acc: 0.8035, val_loss: 1.7642, val_acc: 0.5192,test_acc: 0.5264
# Epoch: 454, Loss: 0.6404,Train_acc: 0.8131, val_loss: 1.7196, val_acc: 0.5337,test_acc: 0.5370
# Epoch: 455, Loss: 0.6475,Train_acc: 0.8045, val_loss: 1.7232, val_acc: 0.5221,test_acc: 0.5197
# Epoch: 456, Loss: 0.6386,Train_acc: 0.7891, val_loss: 1.7700, val_acc: 0.5029,test_acc: 0.5130
# Epoch: 457, Loss: 0.6506,Train_acc: 0.7984, val_loss: 1.8135, val_acc: 0.5202,test_acc: 0.5159
# Epoch: 458, Loss: 0.6411,Train_acc: 0.8083, val_loss: 1.7316, val_acc: 0.5317,test_acc: 0.5331
# Epoch: 459, Loss: 0.6471,Train_acc: 0.8045, val_loss: 1.7256, val_acc: 0.5183,test_acc: 0.5245
# Epoch: 460, Loss: 0.6465,Train_acc: 0.7926, val_loss: 1.7882, val_acc: 0.5115,test_acc: 0.5197
# Epoch: 461, Loss: 0.6453,Train_acc: 0.7929, val_loss: 1.7551, val_acc: 0.5144,test_acc: 0.5139
# Epoch: 462, Loss: 0.6313,Train_acc: 0.8013, val_loss: 1.7751, val_acc: 0.5260,test_acc: 0.5322
# Epoch: 463, Loss: 0.6424,Train_acc: 0.8058, val_loss: 1.7452, val_acc: 0.5308,test_acc: 0.5379
# Epoch: 464, Loss: 0.6463,Train_acc: 0.7990, val_loss: 1.7674, val_acc: 0.5115,test_acc: 0.5264
# Epoch: 465, Loss: 0.6386,Train_acc: 0.7936, val_loss: 1.8015, val_acc: 0.5096,test_acc: 0.5197
# Epoch: 466, Loss: 0.6439,Train_acc: 0.7971, val_loss: 1.7527, val_acc: 0.5192,test_acc: 0.5255
# Epoch: 467, Loss: 0.6404,Train_acc: 0.8038, val_loss: 1.7528, val_acc: 0.5221,test_acc: 0.5322
# Epoch: 468, Loss: 0.6361,Train_acc: 0.8051, val_loss: 1.7792, val_acc: 0.5144,test_acc: 0.5235
# Epoch: 469, Loss: 0.6414,Train_acc: 0.7917, val_loss: 1.7590, val_acc: 0.5067,test_acc: 0.5159
# Epoch: 470, Loss: 0.6515,Train_acc: 0.7936, val_loss: 1.7696, val_acc: 0.5048,test_acc: 0.5139
# Epoch: 471, Loss: 0.6423,Train_acc: 0.8029, val_loss: 1.7409, val_acc: 0.5183,test_acc: 0.5245
# Epoch: 472, Loss: 0.6379,Train_acc: 0.8022, val_loss: 1.7561, val_acc: 0.5183,test_acc: 0.5245
# Epoch: 473, Loss: 0.6482,Train_acc: 0.7962, val_loss: 1.8102, val_acc: 0.5115,test_acc: 0.5159
# Epoch: 474, Loss: 0.6356,Train_acc: 0.7907, val_loss: 1.7529, val_acc: 0.5048,test_acc: 0.5130
# Epoch: 475, Loss: 0.6449,Train_acc: 0.8006, val_loss: 1.7480, val_acc: 0.5125,test_acc: 0.5197
# Epoch: 476, Loss: 0.6394,Train_acc: 0.8090, val_loss: 1.7704, val_acc: 0.5279,test_acc: 0.5370
# Epoch: 477, Loss: 0.6401,Train_acc: 0.8016, val_loss: 1.8239, val_acc: 0.5144,test_acc: 0.5264
# Epoch: 478, Loss: 0.6346,Train_acc: 0.7933, val_loss: 1.7632, val_acc: 0.5019,test_acc: 0.5168
# Epoch: 479, Loss: 0.6383,Train_acc: 0.7904, val_loss: 1.8201, val_acc: 0.5106,test_acc: 0.5178
# Epoch: 480, Loss: 0.6365,Train_acc: 0.8109, val_loss: 1.7393, val_acc: 0.5327,test_acc: 0.5312
# Epoch: 481, Loss: 0.6350,Train_acc: 0.8022, val_loss: 1.7708, val_acc: 0.5250,test_acc: 0.5283
# Epoch: 482, Loss: 0.6383,Train_acc: 0.7981, val_loss: 1.7926, val_acc: 0.5163,test_acc: 0.5130
# Epoch: 483, Loss: 0.6460,Train_acc: 0.7965, val_loss: 1.8127, val_acc: 0.5212,test_acc: 0.5159
# Epoch: 484, Loss: 0.6344,Train_acc: 0.8035, val_loss: 1.7722, val_acc: 0.5183,test_acc: 0.5235
# Epoch: 485, Loss: 0.6354,Train_acc: 0.8038, val_loss: 1.7448, val_acc: 0.5250,test_acc: 0.5245
# Epoch: 486, Loss: 0.6320,Train_acc: 0.8016, val_loss: 1.7827, val_acc: 0.5144,test_acc: 0.5120
# Epoch: 487, Loss: 0.6295,Train_acc: 0.8032, val_loss: 1.8140, val_acc: 0.5115,test_acc: 0.5159
# Epoch: 488, Loss: 0.6368,Train_acc: 0.8035, val_loss: 1.7792, val_acc: 0.5106,test_acc: 0.5159
# Epoch: 489, Loss: 0.6292,Train_acc: 0.8071, val_loss: 1.7809, val_acc: 0.5221,test_acc: 0.5187
# Epoch: 490, Loss: 0.6309,Train_acc: 0.8045, val_loss: 1.7859, val_acc: 0.5192,test_acc: 0.5197
# Epoch: 491, Loss: 0.6308,Train_acc: 0.8006, val_loss: 1.8038, val_acc: 0.5183,test_acc: 0.5139
# Epoch: 492, Loss: 0.6321,Train_acc: 0.8087, val_loss: 1.7407, val_acc: 0.5173,test_acc: 0.5187
# Epoch: 493, Loss: 0.6270,Train_acc: 0.8035, val_loss: 1.7637, val_acc: 0.5212,test_acc: 0.5178
# Epoch: 494, Loss: 0.6319,Train_acc: 0.8077, val_loss: 1.8031, val_acc: 0.5221,test_acc: 0.5226
# Epoch: 495, Loss: 0.6275,Train_acc: 0.7971, val_loss: 1.7891, val_acc: 0.5212,test_acc: 0.5207
# Epoch: 496, Loss: 0.6381,Train_acc: 0.8010, val_loss: 1.7325, val_acc: 0.5173,test_acc: 0.5159
# Epoch: 497, Loss: 0.6251,Train_acc: 0.8019, val_loss: 1.8066, val_acc: 0.5135,test_acc: 0.5197
# Epoch: 498, Loss: 0.6315,Train_acc: 0.7965, val_loss: 1.7843, val_acc: 0.5173,test_acc: 0.5216
# Epoch: 499, Loss: 0.6321,Train_acc: 0.8048, val_loss: 1.8528, val_acc: 0.5192,test_acc: 0.5197
# Epoch: 500, Loss: 0.6323,Train_acc: 0.8026, val_loss: 1.7732, val_acc: 0.5192,test_acc: 0.5149
# Epoch: 501, Loss: 0.6344,Train_acc: 0.8019, val_loss: 1.8105, val_acc: 0.5115,test_acc: 0.5120
# Epoch: 502, Loss: 0.6267,Train_acc: 0.7971, val_loss: 1.7982, val_acc: 0.5144,test_acc: 0.5149
# Epoch: 503, Loss: 0.6383,Train_acc: 0.8061, val_loss: 1.8114, val_acc: 0.5163,test_acc: 0.5159
# Epoch: 504, Loss: 0.6183,Train_acc: 0.8167, val_loss: 1.7790, val_acc: 0.5279,test_acc: 0.5370
# Epoch: 505, Loss: 0.6324,Train_acc: 0.8106, val_loss: 1.7565, val_acc: 0.5154,test_acc: 0.5216
# ...
# Epoch: 282, Loss: 0.7602,Train_acc: 0.7558, val_loss: 1.6196, val_acc: 0.5106,test_acc: 0.5418
# Epoch: 283, Loss: 0.7635,Train_acc: 0.7542, val_loss: 1.6424, val_acc: 0.5010,test_acc: 0.5399
# Epoch: 284, Loss: 0.7603,Train_acc: 0.7381, val_loss: 1.5750, val_acc: 0.4875,test_acc: 0.5341
# Epoch: 285, Loss: 0.7642,Train_acc: 0.7369, val_loss: 1.6031, val_acc: 0.4933,test_acc: 0.5379
# Epoch: 286, Loss: 0.7582,Train_acc: 0.7449, val_loss: 1.6099, val_acc: 0.5000,test_acc: 0.5389
# Epoch: 287, Loss: 0.7546,Train_acc: 0.7590, val_loss: 1.6125, val_acc: 0.5144,test_acc: 0.5408
# Epoch: 288, Loss: 0.7638,Train_acc: 0.7561, val_loss: 1.6342, val_acc: 0.5077,test_acc: 0.5427
# Epoch: 289, Loss: 0.7513,Train_acc: 0.7353, val_loss: 1.5973, val_acc: 0.4942,test_acc: 0.5399
# Epoch: 290, Loss: 0.7581,Train_acc: 0.7362, val_loss: 1.5879, val_acc: 0.4913,test_acc: 0.5418
# Epoch: 291, Loss: 0.7592,Train_acc: 0.7510, val_loss: 1.5938, val_acc: 0.5144,test_acc: 0.5408
# Epoch: 292, Loss: 0.7570,Train_acc: 0.7590, val_loss: 1.6394, val_acc: 0.5096,test_acc: 0.5389
# Epoch: 293, Loss: 0.7528,Train_acc: 0.7433, val_loss: 1.6049, val_acc: 0.4990,test_acc: 0.5360
# Epoch: 294, Loss: 0.7489,Train_acc: 0.7353, val_loss: 1.6354, val_acc: 0.4952,test_acc: 0.5408
# Epoch: 295, Loss: 0.7513,Train_acc: 0.7413, val_loss: 1.6301, val_acc: 0.4952,test_acc: 0.5408
# Epoch: 296, Loss: 0.7548,Train_acc: 0.7625, val_loss: 1.5719, val_acc: 0.5115,test_acc: 0.5341
# Epoch: 297, Loss: 0.7601,Train_acc: 0.7596, val_loss: 1.6046, val_acc: 0.5115,test_acc: 0.5389
# Epoch: 298, Loss: 0.7551,Train_acc: 0.7394, val_loss: 1.6386, val_acc: 0.4933,test_acc: 0.5341
# Epoch: 299, Loss: 0.7552,Train_acc: 0.7372, val_loss: 1.6246, val_acc: 0.4962,test_acc: 0.5341
# Epoch: 300, Loss: 0.7531,Train_acc: 0.7548, val_loss: 1.6103, val_acc: 0.5087,test_acc: 0.5447
# Epoch: 301, Loss: 0.7466,Train_acc: 0.7583, val_loss: 1.6394, val_acc: 0.5115,test_acc: 0.5427
# Epoch: 302, Loss: 0.7539,Train_acc: 0.7468, val_loss: 1.6196, val_acc: 0.4990,test_acc: 0.5399
# Epoch: 303, Loss: 0.7412,Train_acc: 0.7330, val_loss: 1.6354, val_acc: 0.4952,test_acc: 0.5331
# Epoch: 304, Loss: 0.7619,Train_acc: 0.7458, val_loss: 1.6351, val_acc: 0.5010,test_acc: 0.5360
# Epoch: 305, Loss: 0.7488,Train_acc: 0.7571, val_loss: 1.6225, val_acc: 0.5077,test_acc: 0.5370
# Epoch: 306, Loss: 0.7629,Train_acc: 0.7551, val_loss: 1.6067, val_acc: 0.5019,test_acc: 0.5370
# Epoch: 307, Loss: 0.7496,Train_acc: 0.7391, val_loss: 1.6704, val_acc: 0.4981,test_acc: 0.5360
# Epoch: 308, Loss: 0.7516,Train_acc: 0.7397, val_loss: 1.6246, val_acc: 0.4990,test_acc: 0.5379
# Epoch: 309, Loss: 0.7578,Train_acc: 0.7538, val_loss: 1.6461, val_acc: 0.5087,test_acc: 0.5389
# Epoch: 310, Loss: 0.7451,Train_acc: 0.7619, val_loss: 1.6488, val_acc: 0.5135,test_acc: 0.5322
# Epoch: 311, Loss: 0.7566,Train_acc: 0.7596, val_loss: 1.6402, val_acc: 0.5077,test_acc: 0.5418
# Epoch: 312, Loss: 0.7392,Train_acc: 0.7442, val_loss: 1.5809, val_acc: 0.4981,test_acc: 0.5379
# Epoch: 313, Loss: 0.7475,Train_acc: 0.7474, val_loss: 1.6311, val_acc: 0.5058,test_acc: 0.5360
# Epoch: 314, Loss: 0.7395,Train_acc: 0.7554, val_loss: 1.5894, val_acc: 0.5144,test_acc: 0.5408
# Epoch: 315, Loss: 0.7427,Train_acc: 0.7663, val_loss: 1.6180, val_acc: 0.5231,test_acc: 0.5408
# Epoch: 316, Loss: 0.7490,Train_acc: 0.7516, val_loss: 1.6505, val_acc: 0.4942,test_acc: 0.5351
# Epoch: 317, Loss: 0.7466,Train_acc: 0.7452, val_loss: 1.6176, val_acc: 0.4962,test_acc: 0.5408
# Epoch: 318, Loss: 0.7413,Train_acc: 0.7590, val_loss: 1.6372, val_acc: 0.5029,test_acc: 0.5456
# Epoch: 319, Loss: 0.7353,Train_acc: 0.7609, val_loss: 1.6649, val_acc: 0.5106,test_acc: 0.5370
# Epoch: 320, Loss: 0.7387,Train_acc: 0.7571, val_loss: 1.6548, val_acc: 0.5106,test_acc: 0.5456
# Epoch: 321, Loss: 0.7424,Train_acc: 0.7513, val_loss: 1.6430, val_acc: 0.5038,test_acc: 0.5408
# Epoch: 322, Loss: 0.7382,Train_acc: 0.7538, val_loss: 1.6234, val_acc: 0.5010,test_acc: 0.5379
# Epoch: 323, Loss: 0.7323,Train_acc: 0.7596, val_loss: 1.6650, val_acc: 0.5048,test_acc: 0.5427
# Epoch: 324, Loss: 0.7317,Train_acc: 0.7535, val_loss: 1.6225, val_acc: 0.5106,test_acc: 0.5322
# Epoch: 325, Loss: 0.7445,Train_acc: 0.7599, val_loss: 1.6582, val_acc: 0.5144,test_acc: 0.5437
# Epoch: 326, Loss: 0.7343,Train_acc: 0.7548, val_loss: 1.6352, val_acc: 0.4981,test_acc: 0.5408
# Epoch: 327, Loss: 0.7323,Train_acc: 0.7538, val_loss: 1.6387, val_acc: 0.5096,test_acc: 0.5322
# Epoch: 328, Loss: 0.7369,Train_acc: 0.7603, val_loss: 1.6424, val_acc: 0.5144,test_acc: 0.5379
# Epoch: 329, Loss: 0.7280,Train_acc: 0.7567, val_loss: 1.6084, val_acc: 0.5106,test_acc: 0.5168
# Epoch: 330, Loss: 0.7416,Train_acc: 0.7622, val_loss: 1.6575, val_acc: 0.5038,test_acc: 0.5447
# Epoch: 331, Loss: 0.7356,Train_acc: 0.7471, val_loss: 1.6412, val_acc: 0.4962,test_acc: 0.5379
# Epoch: 332, Loss: 0.7448,Train_acc: 0.7564, val_loss: 1.6698, val_acc: 0.5077,test_acc: 0.5418
# Epoch: 333, Loss: 0.7310,Train_acc: 0.7529, val_loss: 1.6408, val_acc: 0.5115,test_acc: 0.5255
# Epoch: 334, Loss: 0.7411,Train_acc: 0.7567, val_loss: 1.6519, val_acc: 0.5106,test_acc: 0.5389
# Epoch: 335, Loss: 0.7293,Train_acc: 0.7571, val_loss: 1.6417, val_acc: 0.5067,test_acc: 0.5447
# Epoch: 336, Loss: 0.7337,Train_acc: 0.7554, val_loss: 1.6597, val_acc: 0.5096,test_acc: 0.5476
# Epoch: 337, Loss: 0.7425,Train_acc: 0.7542, val_loss: 1.6776, val_acc: 0.5173,test_acc: 0.5408
# Epoch: 338, Loss: 0.7282,Train_acc: 0.7532, val_loss: 1.6568, val_acc: 0.5154,test_acc: 0.5408
# Epoch: 339, Loss: 0.7418,Train_acc: 0.7564, val_loss: 1.6759, val_acc: 0.5077,test_acc: 0.5485
# Epoch: 340, Loss: 0.7299,Train_acc: 0.7554, val_loss: 1.6596, val_acc: 0.5048,test_acc: 0.5427
# Epoch: 341, Loss: 0.7329,Train_acc: 0.7657, val_loss: 1.6837, val_acc: 0.5125,test_acc: 0.5466
# Epoch: 342, Loss: 0.7259,Train_acc: 0.7606, val_loss: 1.6746, val_acc: 0.5106,test_acc: 0.5389
# Epoch: 343, Loss: 0.7289,Train_acc: 0.7532, val_loss: 1.6619, val_acc: 0.5058,test_acc: 0.5274
# Epoch: 344, Loss: 0.7232,Train_acc: 0.7606, val_loss: 1.6834, val_acc: 0.5077,test_acc: 0.5476
# Epoch: 345, Loss: 0.7233,Train_acc: 0.7651, val_loss: 1.6456, val_acc: 0.5096,test_acc: 0.5504
# Epoch: 346, Loss: 0.7261,Train_acc: 0.7590, val_loss: 1.6412, val_acc: 0.5029,test_acc: 0.5370
# Epoch: 347, Loss: 0.7231,Train_acc: 0.7615, val_loss: 1.6618, val_acc: 0.5077,test_acc: 0.5370
# Epoch: 348, Loss: 0.7304,Train_acc: 0.7686, val_loss: 1.6728, val_acc: 0.5125,test_acc: 0.5466
# Epoch: 349, Loss: 0.7171,Train_acc: 0.7593, val_loss: 1.6204, val_acc: 0.5067,test_acc: 0.5427
# Epoch: 350, Loss: 0.7297,Train_acc: 0.7628, val_loss: 1.6467, val_acc: 0.5115,test_acc: 0.5466
# Epoch: 351, Loss: 0.7246,Train_acc: 0.7638, val_loss: 1.6674, val_acc: 0.5154,test_acc: 0.5389
# Epoch: 352, Loss: 0.7224,Train_acc: 0.7644, val_loss: 1.6937, val_acc: 0.5096,test_acc: 0.5370
# Epoch: 353, Loss: 0.7325,Train_acc: 0.7635, val_loss: 1.6605, val_acc: 0.5087,test_acc: 0.5456
# Epoch: 354, Loss: 0.7193,Train_acc: 0.7577, val_loss: 1.6419, val_acc: 0.5106,test_acc: 0.5476
# Epoch: 355, Loss: 0.7365,Train_acc: 0.7644, val_loss: 1.6781, val_acc: 0.5154,test_acc: 0.5466
# Epoch: 356, Loss: 0.7152,Train_acc: 0.7644, val_loss: 1.6717, val_acc: 0.5067,test_acc: 0.5351
# Epoch: 357, Loss: 0.7236,Train_acc: 0.7590, val_loss: 1.6758, val_acc: 0.5067,test_acc: 0.5351
# Epoch: 358, Loss: 0.7216,Train_acc: 0.7654, val_loss: 1.6898, val_acc: 0.5077,test_acc: 0.5447
# Epoch: 359, Loss: 0.7210,Train_acc: 0.7708, val_loss: 1.6849, val_acc: 0.5135,test_acc: 0.5456
# Epoch: 360, Loss: 0.7218,Train_acc: 0.7603, val_loss: 1.7136, val_acc: 0.5144,test_acc: 0.5476
# Epoch: 361, Loss: 0.7257,Train_acc: 0.7593, val_loss: 1.6648, val_acc: 0.5038,test_acc: 0.5370
# Epoch: 362, Loss: 0.7166,Train_acc: 0.7654, val_loss: 1.6687, val_acc: 0.5067,test_acc: 0.5427
# Epoch: 363, Loss: 0.7133,Train_acc: 0.7731, val_loss: 1.6482, val_acc: 0.5212,test_acc: 0.5524
# Epoch: 364, Loss: 0.7158,Train_acc: 0.7696, val_loss: 1.6921, val_acc: 0.5202,test_acc: 0.5543
# Epoch: 365, Loss: 0.7139,Train_acc: 0.7599, val_loss: 1.6928, val_acc: 0.5010,test_acc: 0.5379
# Epoch: 366, Loss: 0.7190,Train_acc: 0.7554, val_loss: 1.6424, val_acc: 0.5058,test_acc: 0.5351
# Epoch: 367, Loss: 0.7139,Train_acc: 0.7631, val_loss: 1.6823, val_acc: 0.5212,test_acc: 0.5456
# Epoch: 368, Loss: 0.7132,Train_acc: 0.7747, val_loss: 1.6646, val_acc: 0.5212,test_acc: 0.5476
# Epoch: 369, Loss: 0.7133,Train_acc: 0.7663, val_loss: 1.7288, val_acc: 0.5029,test_acc: 0.5456
# Epoch: 370, Loss: 0.7228,Train_acc: 0.7590, val_loss: 1.7037, val_acc: 0.5010,test_acc: 0.5322
# Epoch: 371, Loss: 0.7122,Train_acc: 0.7564, val_loss: 1.6621, val_acc: 0.5000,test_acc: 0.5379
# Epoch: 372, Loss: 0.7146,Train_acc: 0.7606, val_loss: 1.6801, val_acc: 0.5183,test_acc: 0.5466
# Epoch: 373, Loss: 0.7085,Train_acc: 0.7766, val_loss: 1.6588, val_acc: 0.5260,test_acc: 0.5399
# Epoch: 374, Loss: 0.7100,Train_acc: 0.7689, val_loss: 1.6950, val_acc: 0.5115,test_acc: 0.5456
# Epoch: 375, Loss: 0.7058,Train_acc: 0.7615, val_loss: 1.6905, val_acc: 0.5048,test_acc: 0.5370
# Epoch: 376, Loss: 0.7097,Train_acc: 0.7647, val_loss: 1.6690, val_acc: 0.5077,test_acc: 0.5399
# Epoch: 377, Loss: 0.7173,Train_acc: 0.7737, val_loss: 1.7136, val_acc: 0.5279,test_acc: 0.5427
# Epoch: 378, Loss: 0.7108,Train_acc: 0.7772, val_loss: 1.7216, val_acc: 0.5337,test_acc: 0.5427
# Epoch: 379, Loss: 0.7117,Train_acc: 0.7699, val_loss: 1.6670, val_acc: 0.5087,test_acc: 0.5427
# Epoch: 380, Loss: 0.7096,Train_acc: 0.7587, val_loss: 1.7134, val_acc: 0.5019,test_acc: 0.5360
# Epoch: 381, Loss: 0.7193,Train_acc: 0.7750, val_loss: 1.6842, val_acc: 0.5183,test_acc: 0.5456
# Epoch: 382, Loss: 0.7116,Train_acc: 0.7740, val_loss: 1.6378, val_acc: 0.5231,test_acc: 0.5447
# Epoch: 383, Loss: 0.7134,Train_acc: 0.7782, val_loss: 1.7046, val_acc: 0.5221,test_acc: 0.5495
# Epoch: 384, Loss: 0.7038,Train_acc: 0.7590, val_loss: 1.6991, val_acc: 0.5038,test_acc: 0.5437
# Epoch: 385, Loss: 0.7172,Train_acc: 0.7628, val_loss: 1.6556, val_acc: 0.5038,test_acc: 0.5399
# Epoch: 386, Loss: 0.7057,Train_acc: 0.7753, val_loss: 1.7062, val_acc: 0.5337,test_acc: 0.5456
# Epoch: 387, Loss: 0.7079,Train_acc: 0.7747, val_loss: 1.6887, val_acc: 0.5202,test_acc: 0.5485
# Epoch: 388, Loss: 0.7070,Train_acc: 0.7734, val_loss: 1.6936, val_acc: 0.5212,test_acc: 0.5514
# Epoch: 389, Loss: 0.7056,Train_acc: 0.7638, val_loss: 1.6914, val_acc: 0.5096,test_acc: 0.5437
# Epoch: 390, Loss: 0.7036,Train_acc: 0.7599, val_loss: 1.7018, val_acc: 0.5125,test_acc: 0.5370
# Epoch: 391, Loss: 0.7019,Train_acc: 0.7696, val_loss: 1.6618, val_acc: 0.5260,test_acc: 0.5437
# Epoch: 392, Loss: 0.7047,Train_acc: 0.7763, val_loss: 1.7149, val_acc: 0.5163,test_acc: 0.5485
# Epoch: 393, Loss: 0.7128,Train_acc: 0.7724, val_loss: 1.7073, val_acc: 0.5096,test_acc: 0.5408
# Epoch: 394, Loss: 0.6996,Train_acc: 0.7593, val_loss: 1.6692, val_acc: 0.5077,test_acc: 0.5476
# Epoch: 395, Loss: 0.7077,Train_acc: 0.7712, val_loss: 1.6920, val_acc: 0.5135,test_acc: 0.5485
# Epoch: 396, Loss: 0.7016,Train_acc: 0.7760, val_loss: 1.6899, val_acc: 0.5163,test_acc: 0.5408
# Epoch: 397, Loss: 0.7049,Train_acc: 0.7734, val_loss: 1.6802, val_acc: 0.5125,test_acc: 0.5485
# Epoch: 398, Loss: 0.6968,Train_acc: 0.7734, val_loss: 1.6827, val_acc: 0.5096,test_acc: 0.5476
# Epoch: 399, Loss: 0.6910,Train_acc: 0.7603, val_loss: 1.7044, val_acc: 0.5019,test_acc: 0.5466
# Epoch: 400, Loss: 0.7020,Train_acc: 0.7708, val_loss: 1.6633, val_acc: 0.5260,test_acc: 0.5476
# Epoch: 401, Loss: 0.7021,Train_acc: 0.7817, val_loss: 1.7244, val_acc: 0.5202,test_acc: 0.5389
# Epoch: 402, Loss: 0.6952,Train_acc: 0.7849, val_loss: 1.7101, val_acc: 0.5212,test_acc: 0.5552
# Epoch: 403, Loss: 0.6993,Train_acc: 0.7696, val_loss: 1.7159, val_acc: 0.5029,test_acc: 0.5533
# Epoch: 404, Loss: 0.7073,Train_acc: 0.7619, val_loss: 1.7032, val_acc: 0.5048,test_acc: 0.5418
# Epoch: 405, Loss: 0.7026,Train_acc: 0.7772, val_loss: 1.6700, val_acc: 0.5260,test_acc: 0.5485
# Epoch: 406, Loss: 0.6997,Train_acc: 0.7763, val_loss: 1.6775, val_acc: 0.5154,test_acc: 0.5447
# Epoch: 407, Loss: 0.7148,Train_acc: 0.7788, val_loss: 1.7270, val_acc: 0.5087,test_acc: 0.5504
# Epoch: 408, Loss: 0.7012,Train_acc: 0.7667, val_loss: 1.7209, val_acc: 0.5144,test_acc: 0.5504
# Epoch: 409, Loss: 0.6999,Train_acc: 0.7647, val_loss: 1.6998, val_acc: 0.5144,test_acc: 0.5408
# Epoch: 410, Loss: 0.6988,Train_acc: 0.7840, val_loss: 1.6982, val_acc: 0.5269,test_acc: 0.5495
# Epoch: 411, Loss: 0.6906,Train_acc: 0.7817, val_loss: 1.6771, val_acc: 0.5163,test_acc: 0.5389
# Epoch: 412, Loss: 0.7069,Train_acc: 0.7798, val_loss: 1.7128, val_acc: 0.5144,test_acc: 0.5476
# Epoch: 413, Loss: 0.6875,Train_acc: 0.7644, val_loss: 1.6968, val_acc: 0.5067,test_acc: 0.5379
# Epoch: 414, Loss: 0.7043,Train_acc: 0.7715, val_loss: 1.7148, val_acc: 0.5163,test_acc: 0.5447
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-91-2ec4148e592e> in <cell line: 14>()
#      47     i=0
#      48     for epoch in range(1, 2001):
# ---> 49         loss,val_loss = train(data_train_mask,data_val_mask)
#      50         val_acc = test(data_val_mask)
#      51         train_acc = test(data_train_mask)
#
# <ipython-input-48-3252e0107dce> in train(t, v)
#       4       model.train()
#       5       optimizer.zero_grad()  # Clear gradients.
# ----> 6       out = model(data.x.to(device), data.edge_index.to(device))  # Perform a single forward pass.
#       7       loss = criterion(out[data_train_mask], data.y.to(device)[data_train_mask])  # Compute the loss solely based on the training nodes.
#       8       val_loss = criterion(out[v].to(device), data.y.to(device)[v])  # Compute the loss solely based on the val nodes.
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# <ipython-input-90-9f130ed7d50e> in forward(self, x, edge_index)
#       8
#       9     def forward(self, x, edge_index):
# ---> 10         x = self.conv1(x.to(device), edge_index_curvp.to(device))
#      11         x = x.relu()
#      12         x = F.dropout(x.to(device), p=0.5, training=self.training)
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _wrapped_call_impl(self, *args, **kwargs)
#    1509             return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1510         else:
# -> 1511             return self._call_impl(*args, **kwargs)
#    1512
#    1513     def _call_impl(self, *args, **kwargs):
#
# /usr/local/lib/python3.10/dist-packages/torch/nn/modules/module.py in _call_impl(self, *args, **kwargs)
#    1518                 or _global_backward_pre_hooks or _global_backward_hooks
#    1519                 or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1520             return forward_call(*args, **kwargs)
#    1521
#    1522         try:
#
# /usr/local/lib/python3.10/dist-packages/torch_geometric/nn/conv/gcn_conv.py in forward(self, x, edge_index, edge_weight)
#     261
#     262         # propagate_type: (x: Tensor, edge_weight: OptTensor)
# --> 263         out = self.propagate(edge_index, x=x, edge_weight=edge_weight)
#     264
#     265         if self.bias is not None:
#
# /tmp/torch_geometric.nn.conv.gcn_conv_GCNConv_propagate_tcqsrgju.py in propagate(self, edge_index, x, edge_weight, size)
#     207         # End Message Forward Pre Hook #########################################
#     208
# --> 209         out = self.message(
#     210             x_j=kwargs.x_j,
#     211             edge_weight=kwargs.edge_weight,
#
# KeyboardInterrupt:

# %%
import time
import numpy as np
ramdom = True
moy = []
ep = []
T = []
p_m =[]
nb_runs = 50
hidden_channels = 48
lr = 0.005
weight_decay = 5e-5
moy = []
ep = []
for runs in range(nb_runs):
    #model = GCN(hidden_channels=hidden_channels).to(device)
    model = GAT(hidden_channels=hidden_channels).to(device)
    optimizer = torch.optim.Adam(model.parameters(), lr=lr, weight_decay=weight_decay)

    criterion = torch.nn.CrossEntropyLoss()
    print("runs", runs)
    start_time = time.time()
    shuffled_indices = torch.randperm(len(data.y))
    if ramdom == True :


        indices = [False for i in range(len(data.y))]
        mask_train = [True if i in shuffled_indices[:20*(torch.max(data.y)+1)] else False for i in range(len(indices))]
        mask_val = [True if i in shuffled_indices[20*(torch.max(data.y)+1):20*(torch.max(data.y)+1)+500] else False for i in range(len(indices))]
        mask_test = [True if i in shuffled_indices[20*(torch.max(data.y)+1)+500:20*(torch.max(data.y)+1)+1500] else False for i in range(len(indices))]

        data_train_mask = torch.tensor(mask_train)
        data_val_mask = torch.tensor(mask_val)
        data_test_mask = torch.tensor(mask_test)


    indices = [False for i in range(len(data.y))]
    mask_train = [True if i in shuffled_indices[:int(0.6*len(data.y))] else False for i in range(len(indices))]
    mask_val = [True if i in shuffled_indices[int(0.6*len(data.y)):int(0.8*len(data.y))] else False for i in range(len(indices))]
    mask_test = [True if i in shuffled_indices[int(0.8*len(data.y)):len(data.y)] else False for i in range(len(indices))]


    data_train_mask = torch.tensor(mask_train)
    data_val_mask = torch.tensor(mask_val)
    data_test_mask = torch.tensor(mask_test)

    best_val_acc = 0
    i=0
    for epoch in range(1, 2001):
        loss,val_loss = train(data_train_mask,data_val_mask)
        val_acc = test(data_val_mask)
        train_acc = test(data_train_mask)
        test_acc = test(data_test_mask)
        if val_acc > best_val_acc :
          best_val_acc = val_acc
          Test_acc = test_acc
          i=0
        i=i+1
        #print(f'Epoch: {epoch:03d}, Loss: {loss:.4f},Train_acc: {train_acc:.4f}, val_loss: {val_loss:.4f}, val_acc: {val_acc:.4f},test_acc: {test_acc:.4f}')
        #print(i)
        if i == 100 :
          break

    T.append(time.time() - start_time)
    print(f'Test Accuracy: {Test_acc:.4f}')
    moy.append(Test_acc)
    ep.append(epoch)
print("-------------------------" )
print("mod" , model)
print("hidden_channels" , hidden_channels)
print("weight_decay" , weight_decay)
print("lr" , lr)
print("moyenne" , np.mean(moy))
print("std" , np.std(moy))
print("temps" , np.mean(T))
print((2*(np.std(moy))/(10))*100)


print("-------------------------" )
#moyenne 0.6517647058823529 simple
#moyenne 0.66 double
#moyenne 0.6490196078431374 (two hop)
# Out:
# runs 0
# Test Accuracy: 0.6447
# runs 1
# Test Accuracy: 0.6754
# runs 2
# Test Accuracy: 0.6776
# runs 3
# Test Accuracy: 0.6491
# runs 4
# Test Accuracy: 0.6732
# runs 5
# Test Accuracy: 0.6294
# runs 6
# Test Accuracy: 0.6908
# runs 7
# Test Accuracy: 0.6623
# runs 8
# Test Accuracy: 0.6535
# runs 9
# Test Accuracy: 0.6711
# runs 10
# Test Accuracy: 0.6447
# runs 11
# Test Accuracy: 0.6732
# runs 12
# Test Accuracy: 0.6338
# runs 13
# Test Accuracy: 0.6404
# runs 14
# Test Accuracy: 0.6776
# runs 15
# Test Accuracy: 0.6228
# runs 16
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-16-60293b1ed869> in <cell line: 14>()
#      47     i=0
#      48     for epoch in range(1, 2001):
# ---> 49         loss,val_loss = train(data_train_mask,data_val_mask)
#      50         val_acc = test(data_val_mask)
#      51         train_acc = test(data_train_mask)
#
# <ipython-input-12-3252e0107dce> in train(t, v)
#       4       model.train()
#       5       optimizer.zero_grad()  # Clear gradients.
# ----> 6       out = model(data.x.to(device), data.edge_index.to(device))  # Perform a single forward pass.
#       7       loss = criterion(out[data_train_mask], data.y.to(device)[data_train_mask])  # Compute the loss solely based on the training nodes.
#       8       val_loss = criterion(out[v].to(device), data.y.to(device)[v])  # Compute the loss solely based on the val nodes.
#
# KeyboardInterrupt:

# %% [markdown]
# Calcul du Spectral Gap normalisé

# %%
from torch_geometric.utils import to_dense_adj
def spectral_gap(adj):
    Adj = to_dense_adj(adj.squeeze()).squeeze()
    G = nx.Graph(Adj.numpy())
    eigenvalues = nx.normalized_laplacian_spectrum(G)

    sorted_indices = np.argsort(eigenvalues)[::-1]
    eigenvalues_sorted = eigenvalues[sorted_indices]

    spectral_gap = eigenvalues_sorted[1]
    sum_of_eigenvalues = np.sum(eigenvalues_sorted[1:])

    normalized_spectral_gap = spectral_gap / sum_of_eigenvalues
    return normalized_spectral_gap

# %%
after1 = spectral_gap(two_hop_tensor)#edge_index_curvp
before = spectral_gap(data_und)
print("improvement of the spectral gap of", ((after1 - before)/before)*100, "%" )
# Out:
# improvement of the spectral gap of -19.70755316810613 %

# %%
after = spectral_gap(edge_index_curvm)#edge_index_curvp
#before = spectral_gap(data_und)
print("improvement of the spectral gap of", ((after - before)/before)*100, "%" )
# Out:
# improvement of the spectral gap of 63.122031313100145 %

# %% [markdown]
# actor

# %%
import torch
import torch.nn.functional as F
import numpy as np
from sklearn.metrics import pairwise_distances

#releated paper:(AAAI2020) Measuring and Relieving the Over-smoothing Problem for Graph Neural Networks from the Topological View.
#https://aaai.org/ojs/index.php/AAAI/article/view/5747

#the numpy version for mad (Be able to compute quickly)
#in_arr:[node_num * hidden_dim], the node feature matrix;
#mask_arr: [node_num * node_num], the mask matrix of the target raltion;
#target_idx = [1,2,3...n], the nodes idx for which we calculate the mad value;
def mad_value(in_arr, mask_arr, distance_metric='cosine', digt_num=4, target_idx =None):
    dist_arr = pairwise_distances(in_arr, in_arr, metric=distance_metric)

    mask_dist = np.multiply(dist_arr,mask_arr)

    divide_arr = (mask_dist != 0).sum(1) + 1e-8

    node_dist = mask_dist.sum(1) / divide_arr

    #if target_idx.any()==None:
    mad = np.mean(node_dist)
    #else:
        #node_dist = np.multiply(node_dist,target_idx)
        #mad = node_dist.sum()/((node_dist!=0).sum()+1e-8)

    mad = round(mad, digt_num)

    return mad

with torch.no_grad():
  features = model(data.x, edge_index_curvm)
adj_V = to_dense_adj(edge_index_curvm).squeeze().numpy()
mad_value(features.cpu().numpy() , adj_V)
# Out:
# 0.1339

# %%
with torch.no_grad():
  features = model(data.x, data_und)
adj_V = to_dense_adj(data_und).squeeze().numpy()
mad_value(features.cpu().numpy() , adj_V)
# Out:
# 0.3912
